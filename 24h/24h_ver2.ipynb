# %%
#importing library
from bs4 import BeautifulSoup,NavigableString, Comment
import requests
import time
import re
from datetime import datetime
import html5lib
def remove_div(article):
    divs = article.find_all('div')
    empty_divs = [div for div in divs if not div.text.strip() and not div.contents]
    if not empty_divs:
        return  # No more empty divs, stop recursion
    for div in empty_divs:
        div.decompose()
def get_content(url):
    response = requests.get(url)
    time.sleep(3)
    soup = BeautifulSoup(response.content,  'html.parser')
    try:
        article = soup.find('article', class_ = 'cate-24h-foot-arti-deta-info')
        #remove the last 4 element
        try:
            article.find('p', class_ = 'tuht_all').decompose()
            article.find('div',class_  = 'bv-lq').decompose()
            article.find('div', id = 'zone_banner_sponser_product').decompose()
            article.find('p', class_ = 'linkOrigin').decompose()
            
            article.find('div', class_ = 'block-quiz').decompose()
            article.find('div', class_ = 'podcasts-eva-t').decompose()
        except AttributeError as e:
            print(e)
        tags_to_remove = article.find_all(['a', 'span'])
        tags_to_remove = article.find_all(['span'])
        for tag in tags_to_remove:
            # Extract the text from the tag
            tag_text = tag.get_text()
            # Replace the tag with its text content
            tag.replace_with(tag_text)
            tag.text.strip()
        a_tags_to_remove = article.find_all('a', class_ = "TextlinkBaiviet" )
        for a in a_tags_to_remove:
            # Extract the text from the tag
            tag_text = a .get_text()
            # Replace the tag with its text content
            a .replace_with(tag_text)
            a .text.strip()
        # set attribut for img
        # set attribut for img
        b = article.find_all('img')
        for i in b:
            if '.svg' in i['src']:
                i.decompose()
        for i in article.find_all('img'):
            if 'data-original' in i.attrs.keys():
                i['src'] = i.get('data-original')
            #i.attrs = ['class', 'alt', 'src', 'data-original']
            del i['onclick']
            del i['style']
            del i['class']
        #remove js  and css
        h2 = soup.find('article', class_ = 'cate-24h-foot-arti-deta-info').find('h2')
        h2_text = '\n'.join(line.strip() for line in h2.get_text().split('\n') if line.strip())
        # Update the text of the h2 tag
        h2.string = h2_text
        #soup2 = BeautifulSoup("", 'html.parser')
        #soup2.append(h2)
        for script_or_style in article(['script', 'style']):
            script_or_style.decompose()
        for i in article.find_all(recursive = True):
            if i.name != 'p':
                try:
                    del i['onclick']
                    del i['id']
                    del i['class']
                    del i['style']
                except AttributeError:
                    continue
                except TypeError:
                    continue
        for i in article.find_all('img'):
            i['class'] = "aligncenter"
            i['width'] = 800
            i['height'] = 400
        for video in article.find_all('video'):
            video.decompose()
        for i in article.find_all('p', class_ = 'img_chu_thich_0407'):
                i['style'] = "text-align: center;"
                del i['class']
        for i in article.find_all('div', {'align': 'center'}):
            i.decompose()
        for element in article.find_all(recursive = True,string=True):
            if isinstance(element, NavigableString) and element.strip() == '':
                element.extract()
        for i in article.find_all('div'):
            if i.children == None and i.string == None:
                i.decompose()
        source_tag = soup.new_tag('i') 
        source_tag.string = "Nguồn: 24h.com.vn"  # Set the content of <i> tag
        # Append the <i> tag as the last child of the <article> tag
        article.append(source_tag)
        remove_div(article)
    except (AttributeError, IndexError, TypeError):
        try:
            article = soup.find('div', id= 'magazine_news')
            strong_text = article.find('div', class_ = 'titZing').find('p').text.strip()
            source_tag = soup.new_tag('h2') 
            source_tag.string = strong_text
            article.insert(0,source_tag)
            article.find('div', class_ = 'titZing').decompose()
            videos = article.find_all('div', class_ = 'videoUpload24h')
            vd_captions = article.find_all('div', class_ = 'mg-video-caption')
            for vd_caption in vd_captions:
                vd_caption.decompose()
            for video in videos:
                video.decompose()
            tags_to_remove = article.find_all(['a', 'span'])
            for tag in tags_to_remove:
                # Extract the text from the tag
                tag_text = tag.get_text()
                # Replace the tag with its text content
                tag.replace_with(tag_text)
                tag.text.strip()
            # set attribut for img
            b = article.find_all('img')
            for i in b:
                if '.svg' in i['src']:
                    i.decompose()
            b = article.find_all('img')
            for i in article.find_all('img'):
                try:
                    if 'imgFullMobile_chuan' in  i.parent['class'] or 'imgFullMobile' in  i.parent['class']:
                        i.decompose()
                except KeyError as e:
                    print(e)   
            for i in article.find_all('img'):
                if 'data-original' in i.attrs.keys():
                    i['src'] = i.get('data-original')
                #i.attrs = ['class', 'alt', 'src', 'data-original']
                #del i['onclick']
                #del i['style']
                #del i['class']
                list_attr = ['src','alt','data-src']
                for i in article.find_all('img'):
                    for j in list(i.attrs.keys()):
                        if j not in list_attr:
                            i.attrs.pop(j)
                for i in article.find_all('img'):
                    if 'https://image-us.24h.com.vn/' not in i['src']:
                        i['src']= i['data-src']
            for script_or_style in article(['script', 'style']):
                script_or_style.decompose()
            for i in article.find_all(recursive = True):
                try:
                    del i['onclick']
                    del i['id']
                    del i['class']
                    del i['style']
                except AttributeError:
                    continue
                    
                except TypeError:
                    continue
            for i in article.find_all('img'):
                i['class'] = "aligncenter"
                i['width'] = 800
                i['height'] = 400
            source_tag = soup.new_tag('i') 
            source_tag.string = "Nguồn: 24h.com.vn"  # Set the content of <i> tag
            #remove empty div or empty space from element
            for i in article.find_all('div',recursive= True):
                if i.string == None:
                    if i.text =='':
                        i.decompose()
            for element in article.find_all(recursive = True,string=True):
                if isinstance(element, NavigableString) and element.strip() == '':
                    element.extract()
            #remove html comment from element   
            for comment in article.find_all(string=lambda text: isinstance(text, Comment)):
                comment.extract()
            # Append the <i> tag as the last child of the <article> tag
            article.append(source_tag)
            remove_div(article)
        except AttributeError as e:
            print(e)
    return article
#convert time from post to the format of output
def convert_string(input_str):
    # Extract the date part using regular expression
    pattern = r'\d{2}/\d{2}/\d{4}'
    date_part = re.search(pattern, input_str).group()
    match = re.search(pattern, input_str)
    if match:
        # Parse the date string into a datetime object
        date_obj = datetime.strptime(date_part, '%d/%m/%Y')
        formatted_date = date_obj.strftime('%Y-%m-%d')
        return formatted_date
    else:
        return ""
#Convert time from post to datetime format
def convert_time_string(posted_date):
    pattern = r'\d{2}/\d{2}/\d{4}'
    match = re.search(pattern, posted_date)

    if match:
        date_string = match.group()

        # Convert to datetime object
        datetime_obj = datetime.strptime(date_string, "%d/%m/%Y")
        return datetime_obj
    else:
        return ''

def get_post(url):
    try:
        response = requests.get(url)
        time.sleep(3)
        soup = BeautifulSoup(response.content, 'html5lib')
        content = get_content(url)
        post_time = soup.find('time', class_ = 'cate-24h-foot-arti-deta-cre-post').text.strip()
        published_date = convert_string(post_time)
        title = soup.find('h1').text.strip()
        #h2 = soup.find('h2').text.strip()
        #images_src = [i.attrs['src'] for i in soup.find('article', class_= 'cate-24h-foot-arti-deta-info').find_all('img')[:-1] if 'svg' not in i.attrs['src']]
        #images_src = [img['data-original'] if 'https://image-us.24h.com.vn' not in img['src'] else img['src'] if 'svg' not in img['src'] else '' for img in soup.find('article', class_ = 'cate-24h-foot-arti-deta-info').find_all('img')[:-1]]
        #text_list = [ child.text for child in soup.find('article', class_= 'cate-24h-foot-arti-deta-info').find_all('p')[:-3] if re.sub(r'\n+', '', child.text) != ""]
        #text_list = [h2] + text_list
        #return content,title,published_date
    except AttributeError:
        try:
            response = requests.get(url)
            time.sleep(3)
            soup = BeautifulSoup(response.content, 'html5lib')
            content = get_content(url)
            post_time = soup.find('div', class_ = 'magazine_event_date').text.strip()
            published_date = convert_string(post_time)
            title = soup.find('div', class_ = 'titZing').text.strip()
        except AttributeError as e:
            print(e)
            content = ''
            title = ''
            published_date= ''
    return content,title,published_date

def filter_list(urls):
    filtered_urls = []
    crawl_time = datetime.fromtimestamp(time.time() - 5*24*3600)
    for i in urls:
        response = requests.get(i)
        soup = BeautifulSoup(response.content, 'html5lib')
        try:
            date_posted = soup.find('time').text.strip()
            date_posted_norm = convert_time_string(date_posted)
            if ( (date_posted_norm.day == crawl_time.day) and (date_posted_norm.month == crawl_time.month) and (date_posted_norm.year == crawl_time.year) ):
                filtered_urls.append(i)
                print(i)
        except AttributeError as e:
            print(e)
            break
    return filtered_urls
def get_list_url(cat_url):
    urls = []
    response = requests.get(cat_url)
    time.sleep(3)
    soup = BeautifulSoup(response.content,'html5lib')
    try:
        news_block  = soup.find('section', id = 'tin_bai_noi_bat_khac')
        try:
            url_list = news_block.find_all('a')
            #print(len(url_list))
            for url in url_list:
                if 'https://www.24h.com.vn/' in url['href']:
                    if url['href'] not in urls:
                        urls.append(url['href'])
            print(len(urls))
        except AttributeError as e:
            print(e)
    except AttributeError as e:
        print(e)
    try:
        news_block  = soup.find('div', class_ = 'cate-24h-foot-home-latest-list')
        try:
            url_list = news_block.find_all('a')
            #print(len(url_list))
            for url in url_list:
                if 'https://www.24h.com.vn/' in url['href']:
                    if url['href'] not in urls:
                        urls.append(url['href'])
            print(len(urls))
        except AttributeError as e:
            print(e)
    except AttributeError as e:
        print(e)
    return urls
def add_list(web_24h_com_vn):
    for i in list(web_24h_com_vn['urls'].keys()):
        for j in list(web_24h_com_vn['urls'][i]['sub-category'].keys()):
            
            urls = get_list_url(web_24h_com_vn['urls'][i]['sub-category'][j]['url'])
            print(i,j,web_24h_com_vn['urls'][i]['sub-category'][j]['url'])
            web_24h_com_vn['urls'][i]['sub-category'][j]['url_list'] = filter_list(urls)

def add_post(web_24h_com_vn):
    for i in list(web_24h_com_vn['urls'].keys()):
        for j in list(web_24h_com_vn['urls'][i]['sub-category'].keys()):
            web_24h_com_vn['urls'][i]['sub-category'][j]['content'] = {}
            list_key = [v for v in range(0,len(web_24h_com_vn['urls'][i]['sub-category'][j]['url_list']))]
            for u in list_key:
                web_24h_com_vn['urls'][i]['sub-category'][j]['content'][u] = {}
                if u != "":
                    web_24h_com_vn['urls'][i]['sub-category'][j]['content'][u]['text'] ,web_24h_com_vn['urls'][i]['sub-category'][j]['content'][u]['title'],web_24h_com_vn['urls'][i]['sub-category'][j]['content'][u]['published_date'] = get_post(web_24h_com_vn['urls'][i]['sub-category'][j]['url_list'][u])
                    print(i,j,web_24h_com_vn['urls'][i]['cate_id'],web_24h_com_vn['urls'][i]['sub-category'][j]['name'],web_24h_com_vn['urls'][i]['sub-category'][j]['name'],web_24h_com_vn['urls'][i]['sub-category'][j]['content'][u]['title'],web_24h_com_vn['urls'][i]['sub-category'][j]['url_list'][u])
                

def get_news():
    web_24h_com_vn = {
        "home_page":"https://www.24h.com.vn/",
        "urls":{
            
            "người đẹp":
            {
            "cate_id":63,
            "url":"https://www.24h.com.vn/hau-truong-ngoi-sao-the-thao-c797.html#",
             "sub-category":{
                0:{"name":"người đẹp thể thao","url":"https://www.24h.com.vn/hau-truong-ngoi-sao-the-thao-c797.html"}
            }
            }
        }
    }
#
    add_list(web_24h_com_vn)
    add_post(web_24h_com_vn)
    return web_24h_com_vn
def send_post_to_5goals(title,content,category_id,published_date):
    # URL of the API endpoint (this is a placeholder and needs to be replaced with the actual URL)
    url = "https://api2023.5goal.com/wp-json/custom/createPost"
    
    # Data to be sent in the POST request
    data = {
        "title": title,
        "content": content,
        "category_id": category_id,
        "token": 'draftpost',#'5goalvodichcmnl',  # Replace with your actual access token
        "published_date": published_date
          # Replace with the actual category ID as required
    }
    
    # Sending the POST request
    response = requests.post(url, data=data)
    
    # Checking the response
    if response.status_code == 200:
        print("The post was successfully created.")
        print("Response:", response.text)  # Prints the response text from the server
        
    else:
        print(f"Failed to create the post. Status code: {response.status_code}")
def main():
    web_24h_com_vn = get_news()
    for i in list(web_24h_com_vn['urls'].keys()):
    #web_24h_com_vn2['url'][i]['cate_id']
        for j in list(web_24h_com_vn['urls'][i]['sub-category']):
            url_list =  web_24h_com_vn['urls'][i]['sub-category'][j]['url_list']
            for t in range(0,len(url_list)):
                text = web_24h_com_vn['urls'][i]['sub-category'][j]['content'][t]['text']
                title = web_24h_com_vn['urls'][i]['sub-category'][j]['content'][t]['title']
                published_date = web_24h_com_vn['urls'][i]['sub-category'][j]['content'][t]['published_date']
                cate_id = web_24h_com_vn['urls'][i]['cate_id']
                print("title: ", title, "\n")
                print("date: ", published_date, "\n")
                print("id: ", cate_id, "\n")
                try:
                    text_len = len(text.text)
                    if text_len <450:
                        print(text.text)
                        continue
                    else:
                         send_post_to_5goals(title,str(text),cate_id,published_date)
                except (AttributeError,TypeError):
                    continue

#if __name__ == '__main__':
    #main()

# %%
main()
# Out:
# 'NoneType' object has no attribute 'find_all'
# 9
# người đẹp 0 https://www.24h.com.vn/hau-truong-ngoi-sao-the-thao-c797.html
# 'str' object has no attribute 'day'

# %%
get_content('https://www.24h.com.vn/the-thao/nguoi-mau-the-hinh-mang-hai-dong-mau-co-vong-eo-con-kien-55cm-c101a1518487.html')
# Out:
# 'NoneType' object has no attribute 'decompose'
# <article class="cate-24h-foot-arti-deta-info"><h2>(Tin thể thao, tin người đẹp) Cô gái mang 2 dòng máu Malaysia và Trung Quốc sở hữu vòng eo "con kiến" đáng mơ ước nhờ tập luyện, bổ sung dinh dưỡng theo cách khoa học.</h2><p>Cathryn Li Yuanling, 34 tuổi là một người đẹp đa tài mang hai dòng máu Malaysia và Trung Quốc. Cô vốn là nghệ sĩ piano, cũng là diễn viên và giờ hoạt động như người mẫu thể hình, chuyên gia dinh dưỡng.</p><p><div><div><img alt='Người mẫu thể hình mang hai dòng máu, có vòng eo "con kiến" 55cm - 1' class="aligncenter" height="400" src="https://image-us.24h.com.vn/upload/4-2023/images/2023-11-13/Nguoi-mau-the-hinh-mang-hai-dong-mau-so-huu-vong-eo-cathrynli_11-1699873612-251-width740height925.jpg" width="800"/><div><div></div></div></div></div></p><p style="text-align: center;">Cathryn Li sở hữu vẻ ngoài lôi cuốn</p><p>Nhờ nỗ lực tập thể hình chăm chỉ, sử dụng dinh dưỡng hợp lý, Cathryn Li có cơ thể cân đối, săn chắc, thon gọn và có những đường cong gợi cảm.</p><p>Theo tờ Sanook, số đo ấn tượng nhất của Cathryn Li chính là "vòng 2", cô gái 34 tuổi có vòng eo chỉ 55cm.</p><p>Công việc hiện tại của Cathryn Li là làm người mẫu, cô cũng là một nhà tư vấn về luyện tập thể hình, chế độ dinh dưỡng. Trên trang Instagram hơn 3 triệu người theo dõi, Cathryn thường xuyên chia sẻ những bài tập, đi kèm khẩu phần ăn tương xứng.</p><p><em>Cùng ngắm những hình ảnh tập luyện của Cathryn trên trang cá nhân </em></p><p><img alt='Người mẫu thể hình mang hai dòng máu, có vòng eo "con kiến" 55cm - 2' class="aligncenter" data-original="https://image-us.24h.com.vn/upload/4-2023/images/2023-11-13/Nguoi-mau-the-hinh-mang-hai-dong-mau-so-huu-vong-eo-cathrynli_12-1699873612-190-width740height921.jpg" height="400" src="https://image-us.24h.com.vn/upload/4-2023/images/2023-11-13/Nguoi-mau-the-hinh-mang-hai-dong-mau-so-huu-vong-eo-cathrynli_12-1699873612-190-width740height921.jpg" width="800"/></p><p><img alt='Người mẫu thể hình mang hai dòng máu, có vòng eo "con kiến" 55cm - 3' class="aligncenter" data-original="https://image-us.24h.com.vn/upload/4-2023/images/2023-11-13/Nguoi-mau-the-hinh-mang-hai-dong-mau-so-huu-vong-eo-cathrynli_13-1699873612-475-width740height925.jpg" height="400" src="https://image-us.24h.com.vn/upload/4-2023/images/2023-11-13/Nguoi-mau-the-hinh-mang-hai-dong-mau-so-huu-vong-eo-cathrynli_13-1699873612-475-width740height925.jpg" width="800"/></p><section><div><div></div></div></section><p><img alt='Người mẫu thể hình mang hai dòng máu, có vòng eo "con kiến" 55cm - 4' class="aligncenter" data-original="https://image-us.24h.com.vn/upload/4-2023/images/2023-11-13/Nguoi-mau-the-hinh-mang-hai-dong-mau-so-huu-vong-eo-cathrynli_14-1699873612-423-width740height925.jpg" height="400" src="https://image-us.24h.com.vn/upload/4-2023/images/2023-11-13/Nguoi-mau-the-hinh-mang-hai-dong-mau-so-huu-vong-eo-cathrynli_14-1699873612-423-width740height925.jpg" width="800"/></p><p style="text-align: center;">Tập luyện nghiêm túc, khoa học giúp người đẹp sở hữu thân hình lý tưởng</p><p><img alt='Người mẫu thể hình mang hai dòng máu, có vòng eo "con kiến" 55cm - 5' class="aligncenter" data-original="https://image-us.24h.com.vn/upload/4-2023/images/2023-11-13/Nguoi-mau-the-hinh-mang-hai-dong-mau-so-huu-vong-eo-cathrynli_10-1699873612-15-width740height921.jpg" height="400" src="https://image-us.24h.com.vn/upload/4-2023/images/2023-11-13/Nguoi-mau-the-hinh-mang-hai-dong-mau-so-huu-vong-eo-cathrynli_10-1699873612-15-width740height921.jpg" width="800"/></p><p><img alt='Người mẫu thể hình mang hai dòng máu, có vòng eo "con kiến" 55cm - 6' class="aligncenter" data-original="https://image-us.24h.com.vn/upload/4-2023/images/2023-11-13/Nguoi-mau-the-hinh-mang-hai-dong-mau-so-huu-vong-eo-cathrynli_9-1699873612-511-width740height925.jpg" height="400" src="https://image-us.24h.com.vn/upload/4-2023/images/2023-11-13/Nguoi-mau-the-hinh-mang-hai-dong-mau-so-huu-vong-eo-cathrynli_9-1699873612-511-width740height925.jpg" width="800"/></p><p><img alt='Người mẫu t ...

# %%
def convert_string(input_str):
    # Extract the date part using regular expression
    pattern = r'\d{2}/\d{2}/\d{4}'
    date_part = re.search(pattern, input_str).group()
    match = re.search(pattern, input_str)
    if match:
        # Parse the date string into a datetime object
        date_obj = datetime.strptime(date_part, '%d/%m/%Y')
        formatted_date = date_obj.strftime('%Y-%m-%d')
        return formatted_date
    else:
        return ""
#Convert time from post to datetime format
def convert_time_string(posted_date):
    pattern = r'\d{2}/\d{2}/\d{4}'
    match = re.search(pattern, posted_date)

    if match:
        date_string = match.group()

        # Convert to datetime object
        datetime_obj = datetime.strptime(date_string, "%d/%m/%Y")
        return datetime_obj
    else:
        return ''

# %%
response = requests.get('https://www.24h.com.vn/cong-nghe-thong-tin/nganh-game-mang-lai-doanh-thu-khung-hon-ca-phim-anh-va-am-nhac-c55a1515859.html')
time.sleep(3)
soup = BeautifulSoup(response.content, 'html5lib')
#content = get_content('https://www.24h.com.vn/the-thao/nguoi-mau-the-hinh-mang-hai-dong-mau-co-vong-eo-con-kien-55cm-c101a1518487.html')
post_time = soup.find('time', class_ = 'cate-24h-foot-arti-deta-cre-post').text.strip()
published_date = convert_string(post_time)
title = soup.find('h1').text.strip()

# %%
published_date
# Out:
# '2023-11-04'

# %%
def remove_div(article):
    divs = article.find_all('div')
    empty_divs = [div for div in divs if not div.text.strip() and not div.contents]
    if not empty_divs:
        return  # No more empty divs, stop recursion
    for div in empty_divs:
        div.decompose()
    remove_div(article)

# %%
remove_div(article)

# %%
response = requests.get('https://www.24h.com.vn/o-to/gia-xe-vinfast-fadil-lan-banh-thang-12-2023-giam-50-lptb-c747a1524609.html')
soup = BeautifulSoup(response.content,  'html.parser')   
#remove the last 4 element
article = soup.find('article', class_ = 'cate-24h-foot-arti-deta-info')
post_time = soup.find('time').text.strip()
published_date = convert_string(post_time)

# %%
published_date
# Out:
# '2023-12-07'

# %%
main()
# Out:
# 11
# 19
# tech 0 https://www.24h.com.vn/game-c69.html
# https://www.24h.com.vn/cong-nghe-thong-tin/hang-ti-thiet-bi-co-ket-noi-bluetooth-nguy-co-bi-xam-nhap-ke-ca-iphone-c55a1524128.html
# https://www.24h.com.vn/cong-nghe-thong-tin/danh-sach-15-ung-dung-mua-sam-thu-thap-du-lieu-nguoi-dung-nhieu-nhat-c55a1524028.html
# https://www.24h.com.vn/cong-nghe-thong-tin/nhung-ung-dung-chan-cuoc-goi-rac-duoc-nhieu-nguoi-su-dung-c55a1524017.html
# 11
# 19
# tech 1 https://www.24h.com.vn/phan-mem-ngoai-c302.html
# https://www.24h.com.vn/cong-nghe-thong-tin/nhung-ung-dung-chan-cuoc-goi-rac-duoc-nhieu-nguoi-su-dung-c55a1524017.html
# https://www.24h.com.vn/cong-nghe-thong-tin/bi-an-vat-the-ma-quai-moi-kinh-thien-van-thay-mot-chan-dung-khac-c55a1524076.html
# 11
# 19
# tech 2 https://www.24h.com.vn/khoa-hoc-c782.html
# https://www.24h.com.vn/cong-nghe-thong-tin/nhung-ung-dung-chan-cuoc-goi-rac-duoc-nhieu-nguoi-su-dung-c55a1524017.html
# 11
# 19
# tech 3 https://www.24h.com.vn/mang-xa-hoi-c889.html
# https://www.24h.com.vn/cong-nghe-thong-tin/nhung-ung-dung-chan-cuoc-goi-rac-duoc-nhieu-nguoi-su-dung-c55a1524017.html
# 11
# 19
# tech 4 https://www.24h.com.vn/thu-thuat-tien-ich-c68.html
# https://www.24h.com.vn/cong-nghe-thong-tin/nhung-ung-dung-chan-cuoc-goi-rac-duoc-nhieu-nguoi-su-dung-c55a1524017.html
# 11
# 19
# tech 5 https://www.24h.com.vn/tim-hieu-virus-c57.html
# https://www.24h.com.vn/cong-nghe-thong-tin/nhung-ung-dung-chan-cuoc-goi-rac-duoc-nhieu-nguoi-su-dung-c55a1524017.html
# 11
# 19
# tech 6 https://www.24h.com.vn/may-in/phu-kien-c291.html
# 11
# 19
# tech 7 https://www.24h.com.vn/kham-pha-cong-nghe-c675.html
# 12
# 18
# youths 0 https://www.24h.com.vn/chuyen-cong-so-c180.html
# 'NoneType' object has no attribute 'text'
# 14
# 20
# youths 1 https://www.24h.com.vn/tinh-yeu-gioi-tinh-c306.html
# https://www.24h.com.vn/ban-tre-cuoc-song/co-dau-nghe-an-vua-khoc-vua-hat-hay-nhu-nuot-dia-c64a1524154.html
# https://www.24h.com.vn/ban-tre-cuoc-song/30-tuoi-chua-manh-tinh-vat-vai-nu-duoc-si-di-hen-ho-dua-ra-yeu-cau-la-c64a1523914.html
# 'NoneType' object has no attribute 'text'
# 14
# 20
# youths 2 https://www.24h.com.vn/ngoai-tinh-c435.html
# 14
# 20
# youths 3 https://www.24h.com.vn/gioi-tre-c434.html
# https://www.24h.com.vn/ban-tre-cuoc-song/co-dau-nghe-an-vua-khoc-vua-hat-hay-nhu-nuot-dia-c64a1524154.html
# https://www.24h.com.vn/ban-tre-cuoc-song/30-tuoi-chua-manh-tinh-vat-vai-nu-duoc-si-di-hen-ho-dua-ra-yeu-cau-la-c64a1523914.html
# https://www.24h.com.vn/ban-tre-cuoc-song/buoi-sang-truoc-khi-ra-toa-nhan-duoc-2-tin-nhan-toi-bat-khoc-quyet-dinh-rut-lai-don-ly-hon-c64a1524046.html
# https://www.24h.com.vn/ban-tre-cuoc-song/ong-noi-can-chau-trai-de-phat-toi-rua-bat-cham-du-luan-trung-quoc-phan-no-khi-biet-su-that-phia-sau-c64a1524116.html
# 'NoneType' object has no attribute 'find_all'
# 5
# youths 4 https://www.24h.com.vn/hotgirl-hot-boy-c64e3398.html
# 14
# 20
# youths 5 https://www.24h.com.vn/nhip-song-tre-c685.html
# 'NoneType' object has no attribute 'find_all'
# 14
# showbiz 0 https://www.24h.com.vn/sao-viet-c757.html
# https://www.24h.com.vn/doi-song-showbiz/cuoc-hon-nhan-kin-tieng-cua-danh-ca-thai-chau-toi-giao-het-tien-cho-vo-giu-c729a1524242.html
# https://www.24h.com.vn/doi-song-showbiz/phuong-oanh-he-lo-hau-truong-chup-anh-cuoi-shark-binh-tich-cuc-tac-nghiep-c729a1524073.html
# https://www.24h.com.vn/doi-song-showbiz/le-duong-bao-lam-noi-ve-viec-moi-tien-cua-fan-tren-livestream-puka-khong-hai-long-c729a1524121.html
# https://www.24h.com.vn/doi-song-showbiz/van-trang-xin-loi-vi-quang-cao-qua-lo-su-that-c729a1524160.html
# https://www.24h.com.vn/doi-song-showbiz/ns-minh-nhi-nhac-lai-su-co-bi-cam-dien-khan-gia-quay-lung-18-nam-truoc-c729a1524110.html
# https://www.24h.com.vn/doi-song-showbiz/dam-cuoi-cua-vinh-thuy-va-ai-nu-nha-dai-gia-tai-da-lat-c729a1524085.html
# https://www.24h.com.vn/giai-tri/nsut-thanh-loc-xin-loi-khan-gia-vi-so-suat-dung-kich-c731a1524043.html
# https://www.24h.com.vn/doi-song-showbiz/nu-ca-si-sinh-con-cho-dai-gia-tung-to-bi-ho-ngoc-ha-chen-ep-c729a1522573.html
# 'NoneType' object has no attribute 'find_all'
# 5
# showbiz 1 https://www.24h.com.vn/gap-go-24h-c729e6820.html
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'find_all'
# 14
# showbiz 2 https://www.24h.com.vn/doi-thoai-cung-sao-c730.html
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'find_all'
# 14
# showbiz 3 https://www.24h.com.vn/sao-chau-a-c759.html
# 14
# 20
# cars 0 https://www.24h.com.vn/tin-tuc-o-to-c332.html
# https://www.24h.com.vn/o-to/gia-xe-honda-city-thang-12-2023-giam-100-le-phi-truoc-ba-c747a1523995.html
# https://www.24h.com.vn/tin-tuc-o-to/co-hoi-vang-de-so-huu-toyota-vios-voi-chuong-trinh-khuyen-mai-hap-dan-trong-thang-12-c332a1524197.html
# https://www.24h.com.vn/o-to/xe-dien-hieu-suat-cao-hyundai-ioniq-5-n-lo-dien-anh-thuc-te-c747a1524174.html
# 14
# 22
# cars 1 https://www.24h.com.vn/bang-gia-xe-o-to-c807.html
# https://www.24h.com.vn/o-to/gia-xe-toyota-veloz-cross-lan-banh-thang-12-2023-uu-dai-toi-31-trieu-dong-c747a1523732.html
# https://www.24h.com.vn/o-to/xe-dien-hieu-suat-cao-hyundai-ioniq-5-n-lo-dien-anh-thuc-te-c747a1524174.html
# 11
# 19
# cars 2 https://www.24h.com.vn/tu-van-c240.html
# https://www.24h.com.vn/o-to/xe-dien-hieu-suat-cao-hyundai-ioniq-5-n-lo-dien-anh-thuc-te-c747a1524174.html
# https://www.24h.com.vn/o-to/gia-xe-suzuki-ciaz-niem-yet-va-lan-banh-thang-12-2023-c747a1524007.html
# 11
# 19
# cars 3 https://www.24h.com.vn/anh-nguoi-dep-va-xe-c199.html
# https://www.24h.com.vn/o-to/xe-dien-hieu-suat-cao-hyundai-ioniq-5-n-lo-dien-anh-thuc-te-c747a1524174.html
# https://www.24h.com.vn/o-to/gia-xe-suzuki-ciaz-niem-yet-va-lan-banh-thang-12-2023-c747a1524007.html
# 11
# 19
# cars 4 https://www.24h.com.vn/so-sanh-xe-c805.html
# https://www.24h.com.vn/o-to/xe-dien-hieu-suat-cao-hyundai-ioniq-5-n-lo-dien-anh-thuc-te-c747a1524174.html
# https://www.24h.com.vn/o-to/gia-xe-suzuki-ciaz-niem-yet-va-lan-banh-thang-12-2023-c747a1524007.html
# tech 0 57 Game Game Hàng tỉ thiết bị có kết nối Bluetooth nguy cơ bị xâm nhập, kể cả iPhone https://www.24h.com.vn/cong-nghe-thong-tin/hang-ti-thiet-bi-co-ket-noi-bluetooth-nguy-co-bi-xam-nhap-ke-ca-iphone-c55a1524128.html
# tech 0 57 Game Game Danh sách 15 ứng dụng mua sắm thu thập dữ liệu người dùng nhiều nhất https://www.24h.com.vn/cong-nghe-thong-tin/danh-sach-15-ung-dung-mua-sam-thu-thap-du-lieu-nguoi-dung-nhieu-nhat-c55a1524028.html
# tech 0 57 Game Game Những ứng dụng chặn cuộc gọi rác được nhiều người sử dụng https://www.24h.com.vn/cong-nghe-thong-tin/nhung-ung-dung-chan-cuoc-goi-rac-duoc-nhieu-nguoi-su-dung-c55a1524017.html
# tech 1 57 Phần mềm Phần mềm Những ứng dụng chặn cuộc gọi rác được nhiều người sử dụng https://www.24h.com.vn/cong-nghe-thong-tin/nhung-ung-dung-chan-cuoc-goi-rac-duoc-nhieu-nguoi-su-dung-c55a1524017.html
# tech 1 57 Phần mềm Phần mềm Bí ẩn vật thể ma quái mỗi kính thiên văn thấy một "chân dung" khác https://www.24h.com.vn/cong-nghe-thong-tin/bi-an-vat-the-ma-quai-moi-kinh-thien-van-thay-mot-chan-dung-khac-c55a1524076.html
# tech 2 57 Khoa học Khoa học Những ứng dụng chặn cuộc gọi rác được nhiều người sử dụng https://www.24h.com.vn/cong-nghe-thong-tin/nhung-ung-dung-chan-cuoc-goi-rac-duoc-nhieu-nguoi-su-dung-c55a1524017.html
# tech 3 57 Mạng xã hội Mạng xã hội Những ứng dụng chặn cuộc gọi rác được nhiều người sử dụng https://www.24h.com.vn/cong-nghe-thong-tin/nhung-ung-dung-chan-cuoc-goi-rac-duoc-nhieu-nguoi-su-dung-c55a1524017.html
# tech 4 57 Thủ thuật - Tiện ích Thủ thuật - Tiện ích Những ứng dụng chặn cuộc gọi rác được nhiều người sử dụng https://www.24h.com.vn/cong-nghe-thong-tin/nhung-ung-dung-chan-cuoc-goi-rac-duoc-nhieu-nguoi-su-dung-c55a1524017.html
# tech 5 57 Sợ Virus Sợ Virus Những ứng dụng chặn cuộc gọi rác được nhiều người sử dụng https://www.24h.com.vn/cong-nghe-thong-tin/nhung-ung-dung-chan-cuoc-goi-rac-duoc-nhieu-nguoi-su-dung-c55a1524017.html
# youths 1 60 Tình yêu - Giới Tính Tình yêu - Giới Tính Cô dâu Nghệ An vừa khóc vừa hát hay như nuốt đĩa https://www.24h.com.vn/ban-tre-cuoc-song/co-dau-nghe-an-vua-khoc-vua-hat-hay-nhu-nuot-dia-c64a1524154.html
# youths 1 60 Tình yêu - Giới Tính Tình yêu - Giới Tính 30 tuổi chưa mảnh tình vắt vai, nữ dược sĩ đi hẹn hò đưa ra “yêu cầu lạ” https://www.24h.com.vn/ban-tre-cuoc-song/30-tuoi-chua-manh-tinh-vat-vai-nu-duoc-si-di-hen-ho-dua-ra-yeu-cau-la-c64a1523914.html
# youths 3 60 Giới trẻ Giới trẻ Cô dâu Nghệ An vừa khóc vừa hát hay như nuốt đĩa https://www.24h.com.vn/ban-tre-cuoc-song/co-dau-nghe-an-vua-khoc-vua-hat-hay-nhu-nuot-dia-c64a1524154.html
# youths 3 60 Giới trẻ Giới trẻ 30 tuổi chưa mảnh tình vắt vai, nữ dược sĩ đi hẹn hò đưa ra “yêu cầu lạ” https://www.24h.com.vn/ban-tre-cuoc-song/30-tuoi-chua-manh-tinh-vat-vai-nu-duoc-si-di-hen-ho-dua-ra-yeu-cau-la-c64a1523914.html
# youths 3 60 Giới trẻ Giới trẻ Buổi sáng trước khi ra tòa, nhận được 2 tin nhắn tôi bật khóc quyết định rút lại đơn ly hôn https://www.24h.com.vn/ban-tre-cuoc-song/buoi-sang-truoc-khi-ra-toa-nhan-duoc-2-tin-nhan-toi-bat-khoc-quyet-dinh-rut-lai-don-ly-hon-c64a1524046.html
# youths 3 60 Giới trẻ Giới trẻ Ông nội cắn cháu trai để phạt tội rửa bát chậm, dư luận Trung Quốc phẫn nộ khi biết sự thật phía sau https://www.24h.com.vn/ban-tre-cuoc-song/ong-noi-can-chau-trai-de-phat-toi-rua-bat-cham-du-luan-trung-quoc-phan-no-khi-biet-su-that-phia-sau-c64a1524116.html
# showbiz 0 59 Sao Việt Sao Việt Cuộc hôn nhân kín tiếng của danh ca Thái Châu: “Tôi giao hết tiền cho vợ giữ” https://www.24h.com.vn/doi-song-showbiz/cuoc-hon-nhan-kin-tieng-cua-danh-ca-thai-chau-toi-giao-het-tien-cho-vo-giu-c729a1524242.html
# showbiz 0 59 Sao Việt Sao Việt Phương Oanh hé lộ hậu trường chụp ảnh cưới, Shark Bình tích cực "tác nghiệp" https://www.24h.com.vn/doi-song-showbiz/phuong-oanh-he-lo-hau-truong-chup-anh-cuoi-shark-binh-tich-cuc-tac-nghiep-c729a1524073.html
# showbiz 0 59 Sao Việt Sao Việt Lê Dương Bảo Lâm nói về việc “moi tiền” của fan trên livestream, Puka không hài lòng https://www.24h.com.vn/doi-song-showbiz/le-duong-bao-lam-noi-ve-viec-moi-tien-cua-fan-tren-livestream-puka-khong-hai-long-c729a1524121.html
# showbiz 0 59 Sao Việt Sao Việt Vân Trang xin lỗi vì quảng cáo "quá lố sự thật" https://www.24h.com.vn/doi-song-showbiz/van-trang-xin-loi-vi-quang-cao-qua-lo-su-that-c729a1524160.html
# showbiz 0 59 Sao Việt Sao Việt NS Minh Nhí nhắc lại sự cố bị cấm diễn, khán giả quay lưng 18 năm trước https://www.24h.com.vn/doi-song-showbiz/ns-minh-nhi-nhac-lai-su-co-bi-cam-dien-khan-gia-quay-lung-18-nam-truoc-c729a1524110.html
# showbiz 0 59 Sao Việt Sao Việt Đám cưới của Vĩnh Thụy và ái nữ nhà đại gia tại Đà Lạt https://www.24h.com.vn/doi-song-showbiz/dam-cuoi-cua-vinh-thuy-va-ai-nu-nha-dai-gia-tai-da-lat-c729a1524085.html
# showbiz 0 59 Sao Việt Sao Việt NSƯT Thành Lộc xin lỗi khán giả vì sơ suất dựng kịch https://www.24h.com.vn/giai-tri/nsut-thanh-loc-xin-loi-khan-gia-vi-so-suat-dung-kich-c731a1524043.html
# showbiz 0 59 Sao Việt Sao Việt Nữ ca sĩ sinh con cho đại gia, từng "tố" bị Hồ Ngọc Hà chèn ép https://www.24h.com.vn/doi-song-showbiz/nu-ca-si-sinh-con-cho-dai-gia-tung-to-bi-ho-ngoc-ha-chen-ep-c729a1522573.html
# cars 0 58 Tin tức ô tô Tin tức ô tô Giá xe Honda City tháng 12/2023, giảm 100% lệ phí trước bạ https://www.24h.com.vn/o-to/gia-xe-honda-city-thang-12-2023-giam-100-le-phi-truoc-ba-c747a1523995.html
# 'NoneType' object has no attribute 'find'
# 'NoneType' object has no attribute 'find'
# 'NoneType' object has no attribute 'find_all'
# cars 0 58 Tin tức ô tô Tin tức ô tô  https://www.24h.com.vn/tin-tuc-o-to/co-hoi-vang-de-so-huu-toyota-vios-voi-chuong-trinh-khuyen-mai-hap-dan-trong-thang-12-c332a1524197.html
# cars 0 58 Tin tức ô tô Tin tức ô tô Xe điện hiệu suất cao Hyundai Ioniq 5 N lộ diện ảnh thực tế https://www.24h.com.vn/o-to/xe-dien-hieu-suat-cao-hyundai-ioniq-5-n-lo-dien-anh-thuc-te-c747a1524174.html
# cars 1 58 Bảng giá xe ô tô Bảng giá xe ô tô Giá xe Toyota Veloz Cross lăn bánh tháng 12/2023, ưu đãi tới 31 triệu đồng https://www.24h.com.vn/o-to/gia-xe-toyota-veloz-cross-lan-banh-thang-12-2023-uu-dai-toi-31-trieu-dong-c747a1523732.html
# cars 1 58 Bảng giá xe ô tô Bảng giá xe ô tô Xe điện hiệu suất cao Hyundai Ioniq 5 N lộ diện ảnh thực tế https://www.24h.com.vn/o-to/xe-dien-hieu-suat-cao-hyundai-ioniq-5-n-lo-dien-anh-thuc-te-c747a1524174.html
# cars 2 58 Tư vấn Tư vấn Xe điện hiệu suất cao Hyundai Ioniq 5 N lộ diện ảnh thực tế https://www.24h.com.vn/o-to/xe-dien-hieu-suat-cao-hyundai-ioniq-5-n-lo-dien-anh-thuc-te-c747a1524174.html
# cars 2 58 Tư vấn Tư vấn Giá xe Suzuki Ciaz niêm yết và lăn bánh tháng 12/2023 https://www.24h.com.vn/o-to/gia-xe-suzuki-ciaz-niem-yet-va-lan-banh-thang-12-2023-c747a1524007.html
# cars 3 58 Ngắm xe Ngắm xe Xe điện hiệu suất cao Hyundai Ioniq 5 N lộ diện ảnh thực tế https://www.24h.com.vn/o-to/xe-dien-hieu-suat-cao-hyundai-ioniq-5-n-lo-dien-anh-thuc-te-c747a1524174.html
# cars 3 58 Ngắm xe Ngắm xe Giá xe Suzuki Ciaz niêm yết và lăn bánh tháng 12/2023 https://www.24h.com.vn/o-to/gia-xe-suzuki-ciaz-niem-yet-va-lan-banh-thang-12-2023-c747a1524007.html
# cars 4 58 Đánh giá xe Đánh giá xe Xe điện hiệu suất cao Hyundai Ioniq 5 N lộ diện ảnh thực tế https://www.24h.com.vn/o-to/xe-dien-hieu-suat-cao-hyundai-ioniq-5-n-lo-dien-anh-thuc-te-c747a1524174.html
# cars 4 58 Đánh giá xe Đánh giá xe Giá xe Suzuki Ciaz niêm yết và lăn bánh tháng 12/2023 https://www.24h.com.vn/o-to/gia-xe-suzuki-ciaz-niem-yet-va-lan-banh-thang-12-2023-c747a1524007.html
# title:  Hàng tỉ thiết bị có kết nối Bluetooth nguy cơ bị xâm nhập, kể cả iPhone
#
# date:  2023-12-04
#
# id:  57
#
# The post was successfully created.
# Response: {"success":false,"error_message":"B\u00e0i vi\u1ebft \u0111\u00e3 t\u1ed3n t\u1ea1i."}
# title:  Danh sách 15 ứng dụng mua sắm thu thập dữ liệu người dùng nhiều nhất
#
# date:  2023-12-04
#
# id:  57
#
# The post was successfully created.
# Response: {"success":false,"error_message":"B\u00e0i vi\u1ebft \u0111\u00e3 t\u1ed3n t\u1ea1i."}
# title:  Những ứng dụng chặn cuộc gọi rác được nhiều người sử dụng
#
# date:  2023-12-04
#
# id:  57
#
# The post was successfully created.
# Response: {"success":false,"error_message":"B\u00e0i vi\u1ebft \u0111\u00e3 t\u1ed3n t\u1ea1i."}
# title:  Những ứng dụng chặn cuộc gọi rác được nhiều người sử dụng
#
# date:  2023-12-04
#
# id:  57
#
# The post was successfully created.
# Response: {"success":false,"error_message":"B\u00e0i vi\u1ebft \u0111\u00e3 t\u1ed3n t\u1ea1i."}
# title:  Bí ẩn vật thể ma quái mỗi kính thiên văn thấy một "chân dung" khác
#
# date:  2023-12-04
#
# id:  57
#
# The post was successfully created.
# Response: {"success":false,"error_message":"B\u00e0i vi\u1ebft \u0111\u00e3 t\u1ed3n t\u1ea1i."}
# title:  Những ứng dụng chặn cuộc gọi rác được nhiều người sử dụng
#
# date:  2023-12-04
#
# id:  57
#
# The post was successfully created.
# Response: {"success":false,"error_message":"B\u00e0i vi\u1ebft \u0111\u00e3 t\u1ed3n t\u1ea1i."}
# title:  Những ứng dụng chặn cuộc gọi rác được nhiều người sử dụng
#
# date:  2023-12-04
#
# id:  57
#
# The post was successfully created.
# Response: {"success":false,"error_message":"B\u00e0i vi\u1ebft \u0111\u00e3 t\u1ed3n t\u1ea1i."}
# title:  Những ứng dụng chặn cuộc gọi rác được nhiều người sử dụng
#
# date:  2023-12-04
#
# id:  57
#
# The post was successfully created.
# Response: {"success":false,"error_message":"B\u00e0i vi\u1ebft \u0111\u00e3 t\u1ed3n t\u1ea1i."}
# title:  Những ứng dụng chặn cuộc gọi rác được nhiều người sử dụng
#
# date:  2023-12-04
#
# id:  57
#
# The post was successfully created.
# Response: {"success":false,"error_message":"B\u00e0i vi\u1ebft \u0111\u00e3 t\u1ed3n t\u1ea1i."}
# title:  Cô dâu Nghệ An vừa khóc vừa hát hay như nuốt đĩa
#
# date:  2023-12-04
#
# id:  60
#
# The post was successfully created.
# Response: {"success":false,"error_message":"B\u00e0i vi\u1ebft \u0111\u00e3 t\u1ed3n t\u1ea1i."}
# title:  30 tuổi chưa mảnh tình vắt vai, nữ dược sĩ đi hẹn hò đưa ra “yêu cầu lạ”
#
# date:  2023-12-04
#
# id:  60
#
# The post was successfully created.
# Response: {"success":false,"error_message":"B\u00e0i vi\u1ebft \u0111\u00e3 t\u1ed3n t\u1ea1i."}
# title:  Cô dâu Nghệ An vừa khóc vừa hát hay như nuốt đĩa
#
# date:  2023-12-04
#
# id:  60
#
# The post was successfully created.
# Response: {"success":false,"error_message":"B\u00e0i vi\u1ebft \u0111\u00e3 t\u1ed3n t\u1ea1i."}
# title:  30 tuổi chưa mảnh tình vắt vai, nữ dược sĩ đi hẹn hò đưa ra “yêu cầu lạ”
#
# date:  2023-12-04
#
# id:  60
#
# The post was successfully created.
# Response: {"success":false,"error_message":"B\u00e0i vi\u1ebft \u0111\u00e3 t\u1ed3n t\u1ea1i."}
# title:  Buổi sáng trước khi ra tòa, nhận được 2 tin nhắn tôi bật khóc quyết định rút lại đơn ly hôn
#
# date:  2023-12-04
#
# id:  60
#
# The post was successfully created.
# Response: {"success":false,"error_message":"B\u00e0i vi\u1ebft \u0111\u00e3 t\u1ed3n t\u1ea1i."}
# title:  Ông nội cắn cháu trai để phạt tội rửa bát chậm, dư luận Trung Quốc phẫn nộ khi biết sự thật phía sau
#
# date:  2023-12-04
#
# id:  60
#
# The post was successfully created.
# Response: {"success":false,"error_message":"B\u00e0i vi\u1ebft \u0111\u00e3 t\u1ed3n t\u1ea1i."}
# title:  Cuộc hôn nhân kín tiếng của danh ca Thái Châu: “Tôi giao hết tiền cho vợ giữ”
#
# date:  2023-12-04
#
# id:  59
#
# The post was successfully created.
# Response: {"success":false,"error_message":"B\u00e0i vi\u1ebft \u0111\u00e3 t\u1ed3n t\u1ea1i."}
# title:  Phương Oanh hé lộ hậu trường chụp ảnh cưới, Shark Bình tích cực "tác nghiệp"
#
# date:  2023-12-04
#
# id:  59
#
# The post was successfully created.
# Response: {"success":true,"post_id":66379}
# title:  Lê Dương Bảo Lâm nói về việc “moi tiền” của fan trên livestream, Puka không hài lòng
#
# date:  2023-12-04
#
# id:  59
#
# The post was successfully created.
# Response: {"success":false,"error_message":"B\u00e0i vi\u1ebft \u0111\u00e3 t\u1ed3n t\u1ea1i."}
# title:  Vân Trang xin lỗi vì quảng cáo "quá lố sự thật"
#
# date:  2023-12-04
#
# id:  59
#
# The post was successfully created.
# Response: {"success":false,"error_message":"B\u00e0i vi\u1ebft \u0111\u00e3 t\u1ed3n t\u1ea1i."}
# title:  NS Minh Nhí nhắc lại sự cố bị cấm diễn, khán giả quay lưng 18 năm trước
#
# date:  2023-12-04
#
# id:  59
#
# The post was successfully created.
# Response: {"success":false,"error_message":"B\u00e0i vi\u1ebft \u0111\u00e3 t\u1ed3n t\u1ea1i."}
# title:  Đám cưới của Vĩnh Thụy và ái nữ nhà đại gia tại Đà Lạt
#
# date:  2023-12-04
#
# id:  59
#
# The post was successfully created.
# Response: {"success":false,"error_message":"B\u00e0i vi\u1ebft \u0111\u00e3 t\u1ed3n t\u1ea1i."}
# title:  NSƯT Thành Lộc xin lỗi khán giả vì sơ suất dựng kịch
#
# date:  2023-12-04
#
# id:  59
#
# The post was successfully created.
# Response: {"success":false,"error_message":"B\u00e0i vi\u1ebft \u0111\u00e3 t\u1ed3n t\u1ea1i."}
# title:  Nữ ca sĩ sinh con cho đại gia, từng "tố" bị Hồ Ngọc Hà chèn ép
#
# date:  2023-12-04
#
# id:  59
#
# Sao nữ này từng gây nhiều chú ý khi tố Hồ Ngọc Hà chèn ép, không cho tham gia một chương trình truyền hình.1Sao nữ nào sau đây từng tố bị Hồ Ngọc Hà chèn ép, không cho ngồi ghế nóng một chương trình?A. Thanh HằngB. Minh HằngC. Võ Hoàng YếnD. Anh Thư(Bấm vào bất kì vị trí nào trên khung ảnh để chọn)Nguồn: 24h.com.vn
# title:  Giá xe Honda City tháng 12/2023, giảm 100% lệ phí trước bạ
#
# date:  2023-12-04
#
# id:  58
#
# The post was successfully created.
# Response: {"success":false,"error_message":"B\u00e0i vi\u1ebft \u0111\u00e3 t\u1ed3n t\u1ea1i."}
# title:
#
# date:
#
# id:  58
#
# title:  Xe điện hiệu suất cao Hyundai Ioniq 5 N lộ diện ảnh thực tế
#
# date:  2023-12-04
#
# id:  58
#
# The post was successfully created.
# Response: {"success":false,"error_message":"B\u00e0i vi\u1ebft \u0111\u00e3 t\u1ed3n t\u1ea1i."}
# title:  Giá xe Toyota Veloz Cross lăn bánh tháng 12/2023, ưu đãi tới 31 triệu đồng
#
# date:  2023-12-04
#
# id:  58
#
# The post was successfully created.
# Response: {"success":false,"error_message":"B\u00e0i vi\u1ebft \u0111\u00e3 t\u1ed3n t\u1ea1i."}
# title:  Xe điện hiệu suất cao Hyundai Ioniq 5 N lộ diện ảnh thực tế
#
# date:  2023-12-04
#
# id:  58
#
# The post was successfully created.
# Response: {"success":false,"error_message":"B\u00e0i vi\u1ebft \u0111\u00e3 t\u1ed3n t\u1ea1i."}
# title:  Xe điện hiệu suất cao Hyundai Ioniq 5 N lộ diện ảnh thực tế
#
# date:  2023-12-04
#
# id:  58
#
# The post was successfully created.
# Response: {"success":false,"error_message":"B\u00e0i vi\u1ebft \u0111\u00e3 t\u1ed3n t\u1ea1i."}
# title:  Giá xe Suzuki Ciaz niêm yết và lăn bánh tháng 12/2023
#
# date:  2023-12-04
#
# id:  58
#
# The post was successfully created.
# Response: {"success":false,"error_message":"B\u00e0i vi\u1ebft \u0111\u00e3 t\u1ed3n t\u1ea1i."}
# title:  Xe điện hiệu suất cao Hyundai Ioniq 5 N lộ diện ảnh thực tế
#
# date:  2023-12-04
#
# id:  58
#
# The post was successfully created.
# Response: {"success":false,"error_message":"B\u00e0i vi\u1ebft \u0111\u00e3 t\u1ed3n t\u1ea1i."}
# title:  Giá xe Suzuki Ciaz niêm yết và lăn bánh tháng 12/2023
#
# date:  2023-12-04
#
# id:  58
#
# The post was successfully created.
# Response: {"success":false,"error_message":"B\u00e0i vi\u1ebft \u0111\u00e3 t\u1ed3n t\u1ea1i."}
# title:  Xe điện hiệu suất cao Hyundai Ioniq 5 N lộ diện ảnh thực tế
#
# date:  2023-12-04
#
# id:  58
#
# The post was successfully created.
# Response: {"success":false,"error_message":"B\u00e0i vi\u1ebft \u0111\u00e3 t\u1ed3n t\u1ea1i."}
# title:  Giá xe Suzuki Ciaz niêm yết và lăn bánh tháng 12/2023
#
# date:  2023-12-04
#
# id:  58
#
# The post was successfully created.
# Response: {"success":false,"error_message":"B\u00e0i vi\u1ebft \u0111\u00e3 t\u1ed3n t\u1ea1i."}

# %%
html_content = '''
<article class="cate-24h-foot-arti-deta-info">
<h2>Chiếc ô tô tải cố tình vượt xe khác tại khúc cua và gây ra tai nạn liên hoàn với các xe khác.</h2>
<div align="center"><section>
<div></div>
</section>
<div>
<div>
<div></div>
<div></div>
<div></div>
<div></div>
<div></div>
<div></div>
<div></div>
<div><section>
<div></div>
</section></div>
</div>
<div>
<div></div>
</div>
<div></div>
<div></div>
<div></div>
<div></div>
<div></div>
<div></div>
<div></div>
<div></div>
<div></div>
<div></div>
<div></div>
<div></div>
<div></div>
</div>
</div>
Tại khúc cua khuất tầm nhìn, tài xế xe tải cố tình vượt ô tô con nhưng lại vướng các xe phía trước. Để tránh đâm trực diện, xe tải đánh lái vào trong khiến va chạm với ô tô con. Không những vậy, khi bị đâm ô tô con đã quay 180 độ và đầu xe va chạm với xe khác ở bên làn ngược chiều.
<div>
<div></div>
</div>
<i>Nguồn: 24h.com.vn</i>

</article>
'''
soup = BeautifulSoup(html_content, 'html.parser')
# Out:
# 'Chiếc ô tô tải cố tình vượt xe khác tại khúc cua và gây ra tai nạn liên hoàn với các xe khác.\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nTại khúc cua khuất tầm nhìn, tài xế xe tải cố tình vượt ô tô con nhưng lại vướng các xe phía trước. Để tránh đâm trực diện, xe tải đánh lái vào trong khiến va chạm với ô tô con. Không những vậy, khi bị đâm ô tô con đã quay 180 độ và đầu xe va chạm với xe khác ở bên làn ngược chiều.\n\n\n\nNguồn: 24h.com.vn'

# %%
len(soup.text.strip())
# Out:
# 431

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 4
#       2 def plus_a():
#       3     x.append(10)
# ----> 4 plus_a()
#       5 print(a)
#
# Cell In[61], line 3, in plus_a()
#       2 def plus_a():
# ----> 3     x.append(10)
#
# NameError: name 'x' is not defined
