# %%
import requests 
import time
import re
from datetime import datetime
from bs4 import BeautifulSoup,NavigableString, Comment

# %%
import requests 
import time
import re
from datetime import datetime
from bs4 import BeautifulSoup,NavigableString#, Comment
import lxml
def convert_string(input_str):
    # Regular expression pattern to match a date in the format dd-mm-yyyy
    pattern =r'\d+/\d+/\d+'
    
    # Search for the pattern in the string
    match = re.search(pattern, input_str)
    if match:
    # Extract and print the date if found
        date_str = match.group(0)
        date_obj = datetime.strptime(date_str, '%d/%m/%Y')
        date_str = date_obj.strftime('%Y-%m-%d')
        return date_str,date_obj
    else:
        return None

def get_datetime_obj(string):

    # Regular expression pattern to match the date
    pattern = r'\b\d{2} \w{3} \d{4}\b'
    
    # Search for the pattern in the string and extract the date
    match = re.search(pattern, string)
    if match:
        date_str = match.group(0)
        # Convert the extracted date string to datetime object
        date_obj = datetime.strptime(date_str, '%d %b %Y')
        date_str = date_obj.strftime('%Y-%m-%d')
    else:
        date_obj = None
    
    return date_obj,date_str


def get_content_vnexpress(url):
    response = requests.get(url)
    time.sleep(5)
    soup = BeautifulSoup(response.content, 'html5lib')
    title = soup.find('h1').text.strip()
    date = soup.find('span', class_ = 'date').text.strip()
    published_date = convert_string(date)[0]
    first_paragraph = soup.find('p', class_  = 'description')
    article = soup.find('article', class_ = 'fck_detail')
    
    strong_tag = soup.new_tag('strong') 
    strong_tag.string = first_paragraph.text # Set the content of <i> tag
    
    
    # Insert the new element as the first child
    article.insert(0, strong_tag)
    first_paragraph
    for script_or_style in article(['script', 'style','iframe','video']):
                script_or_style.decompose()
    
    caption_text_list = article.find_all('figcaption')
    tags_to_remove = article.find_all(['a', 'span'])
    for tag in tags_to_remove:
        # Extract the text from the tag
        tag_text = tag.get_text()
        # Replace the tag with its text content
        tag.replace_with(tag_text)
        tag.text.strip()
    #remove all image attributes except somes from list
    list_attr = ['src','alt','data-src']
    for i in article.find_all('img'):
        for j in list(i.attrs.keys()):
            if j not in list_attr:
                i.attrs.pop(j)
    img_list = article.find_all('img')
    n_img = len(img_list)
    for i in range(0,n_img):
           
        caption_start = NavigableString("[caption id=\"\" align=\"aligncenter\" width=\"800\"]")
        try:
            caption_text = NavigableString(caption_text_list[i].get_text())
        except IndexError:
            caption_text = ''
        caption_end = NavigableString("[/caption]")
        # Insert the custom tags and caption text around the <img> tag
        img_list[i].insert_before(caption_start)
        img_list[i].insert_after(caption_end)
        img_list[i].insert_after(caption_text) 
    for i in article.find_all('img'):
        try:
            i['src'] = i['data-src']
        except KeyError:
            continue
    for i in caption_text_list:
        i.decompose()
    """for i in article.find_all(recursive = True):
            try:
                del i['onclick']
                i['id'] =''
                i['class']=''
                i['style'] =''
                i['href'] = ''
            except AttributeError:
                continue
            #try:
                #print(i)
                
            except TypeError:
                continue"""
    for i in article.find_all('img'):
        i['class'] = "aligncenter"
        i['width'] = 800
        i['height'] = 400
        del i['data-src']
    list_attr = ['src','alt','data-src','class']
    for i in article.find_all(recursive = True):
        for j in list(i.attrs.keys()):
            if j not in list_attr:
                i.attrs.pop(j)
    for item in article.find_all('div'):
        if item.string =="":
            item.decompose()
        
    article.find_all('p',recursive = True)[-1].decompose()
    for comment in article.find_all(string=lambda text: isinstance(text, Comment)):
        comment.extract()
    #article.find_all(recursive = True)[-1].decompose()
    #article.find('div', class_ ='width_common box-tinlienquanv2').decompose()
    source_tag = soup.new_tag('i') 
    source_tag.string = "Nguồn: vnexpress.net"  # Set the content of <i> tag
    article.append(source_tag)

    return article, title, published_date
def get_post(url):
    try:
        content,title,published_date = get_content_vnexpress(url)
        return content,title,published_date
    except AttributeError as e:
        print(e)
def get_list_url(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'xml')
    items = soup.find_all('item')
    item_dict = {}
    for i in range(0, len(items)):
        link = items[i].find('link').text.strip()
        date = items[i].find('pubDate').text.strip()
        item_dict[i] = {'link': link, 'date': date}
    return item_dict
def filter_list(urls_dict):
    filtered_urls = []
    crawl_time = datetime.fromtimestamp(time.time()-4*24*3600)
    for i in range(0,len(urls_dict)):
        try:
            date_posted_norm = get_datetime_obj(urls_dict[i]['date'])[0]
            if ( (date_posted_norm.day == crawl_time.day) and (date_posted_norm.month == crawl_time.month) and (date_posted_norm.year == crawl_time.year) ):
                filtered_urls.append(urls_dict[i]['link'])
                #print(i)
        except AttributeError as e:
            print(e)
            continue
    return filtered_urls
#add list url to json
#add list url to json
def add_list(web_json_obj):
    for i in list(web_json_obj['urls'].keys()):
        for j in list(web_json_obj['urls'][i]['sub-category'].keys()):  
            urls = get_list_url(web_json_obj['urls'][i]['sub-category'][j]['url'])
            print(i,j,web_json_obj['urls'][i]['sub-category'][j]['url'])
            web_json_obj['urls'][i]['sub-category'][j]['url_list'] = filter_list(urls)
# add post content from get content function to json object
# add post content from get content function to json object
def add_post(web_json_obj):
    for i in list(web_json_obj['urls'].keys()):
        for j in list(web_json_obj['urls'][i]['sub-category'].keys()):
            web_json_obj['urls'][i]['sub-category'][j]['content'] = {}
            list_key = [v for v in range(0,len(web_json_obj['urls'][i]['sub-category'][j]['url_list']))]
            for u in list_key:
                web_json_obj['urls'][i]['sub-category'][j]['content'][u] = {}
                if u != "":
                    web_json_obj['urls'][i]['sub-category'][j]['content'][u]['text'] ,web_json_obj['urls'][i]['sub-category'][j]['content'][u]['title'],web_json_obj['urls'][i]['sub-category'][j]['content'][u]['published_date'] = get_post(web_json_obj['urls'][i]['sub-category'][j]['url_list'][u])
                    print(i,j,web_json_obj['urls'][i]['sub-category'][j]['cate_id'],web_json_obj['urls'][i]['sub-category'][j]['name'],web_json_obj['urls'][i]['sub-category'][j]['name'],web_json_obj['urls'][i]['sub-category'][j]['content'][u]['title'],web_json_obj['urls'][i]['sub-category'][j]['url_list'][u])
#add all necessary information to json object
def get_news_vnexpress():
    _vnexpress= {
            "home_page":"https://vnexpress.net/",
            "urls":{
                "Công Nghệ":
                {
                 "url":"https://vnexpress.net/rss/so-hoa.rss#",
                 "sub-category":{  
                    0:{"name":"Công nghệ",
                     "url":"https://vnexpress.net/rss/so-hoa.rss",
                     "cate_id":57,
                      "url_list" : []},
                 }
                }
            }
        }
#
    add_list(_vnexpress)
    add_post(_vnexpress)
    return _vnexpress
#send post content to wordpress via endpoint
def send_post_to_5goals(title,content,category_id,published_date):
    # URL of the API endpoint (this is a placeholder and needs to be replaced with the actual URL)
    url = "https://api2023.5goal.com/wp-json/custom/createPost"
    
    # Data to be sent in the POST request
    data = {
        "title": title,
        "content": content,
        "category_id": category_id,
        "token": 'draftpost',#'5goalvodichcmnl',  # Replace with your actual access token
        "published_date": published_date,
        "domain":"vnexpress"
          # Replace with the actual category ID as required
    }
    # Sending the POST request
    response = requests.post(url, data=data)
    
    # Checking the response
    if response.status_code == 200:
        print("The post was successfully created.")
        print("Response:", response.text)  # Prints the response text from the server
    else:
        print(f"Failed to create the post. Status code: {response.status_code}")
def main():
    _vnexpress = get_news_vnexpress()
    for i in list(_vnexpress['urls'].keys()):
    #web_24h_com_vn2['url'][i]['cate_id']
        for j in list(_vnexpress['urls'][i]['sub-category']):
            url_list =  _vnexpress['urls'][i]['sub-category'][j]['url_list']
            print(url_list)
            for t in range(0,len(url_list)):
                content = _vnexpress['urls'][i]['sub-category'][j]['content'][t]['text']
                title = _vnexpress['urls'][i]['sub-category'][j]['content'][t]['title']
                published_date = _vnexpress['urls'][i]['sub-category'][j]['content'][t]['published_date']
                cate_id = _vnexpress['urls'][i]['sub-category'][j]['cate_id']
                print(title, url_list[t])
                send_post_to_5goals(title,str(content), cate_id, published_date)
                time.sleep(2)

# %%
main()
# Out:
# Công Nghệ 0 https://vnexpress.net/rss/so-hoa.rss
# Công Nghệ 0 57 Công nghệ Công nghệ Người dùng ngày càng chuộng iPhone bản đắt tiền https://vnexpress.net/nguoi-dung-ngay-cang-chuong-iphone-ban-dat-tien-4682179.html
# Công Nghệ 0 57 Công nghệ Công nghệ Tài khoản Google không hoạt động sẽ bị xóa từ cuối tuần https://vnexpress.net/tai-khoan-google-khong-hoat-dong-se-bi-xoa-tu-cuoi-tuan-4682171.html
# Công Nghệ 0 57 Công nghệ Công nghệ Kỹ sư ra lệnh - công việc sinh ra trong cơn sốt AI https://vnexpress.net/ky-su-ra-lenh-cong-viec-sinh-ra-trong-con-sot-ai-4681381.html
# Công Nghệ 0 57 Công nghệ Công nghệ CZ và Binance chưa thoát cáo buộc gian lận https://vnexpress.net/cz-va-binance-chua-thoat-cao-buoc-gian-lan-4682136.html
# Công Nghệ 0 57 Công nghệ Công nghệ JBL Authentics 500 - loa dáng hoài cổ giá 17 triệu đồng https://vnexpress.net/jbl-authentics-500-loa-dang-hoai-co-gia-17-trieu-dong-4681951.html
# Công Nghệ 0 57 Công nghệ Công nghệ Meta bị tố cáo làm ngơ trước nội dung độc hại https://vnexpress.net/meta-bi-to-cao-lam-ngo-truoc-noi-dung-doc-hai-4682046.html
# Công Nghệ 0 57 Công nghệ Công nghệ Samsung sắp ra 'AI Phone' https://vnexpress.net/samsung-sap-ra-ai-phone-4681968.html
# Công Nghệ 0 57 Công nghệ Công nghệ Còn ba ngày kết thúc Sơ loại Tech Awards 2023 https://vnexpress.net/con-ba-ngay-ket-thuc-so-loai-tech-awards-2023-4681777.html
# Công Nghệ 0 57 Công nghệ Công nghệ Google Drive gặp lỗi lạ gây mất dữ liệu https://vnexpress.net/google-drive-gap-loi-la-gay-mat-du-lieu-4681957.html
# ['https://vnexpress.net/nguoi-dung-ngay-cang-chuong-iphone-ban-dat-tien-4682179.html', 'https://vnexpress.net/tai-khoan-google-khong-hoat-dong-se-bi-xoa-tu-cuoi-tuan-4682171.html', 'https://vnexpress.net/ky-su-ra-lenh-cong-viec-sinh-ra-trong-con-sot-ai-4681381.html', 'https://vnexpress.net/cz-va-binance-chua-thoat-cao-buoc-gian-lan-4682136.html', 'https://vnexpress.net/jbl-authentics-500-loa-dang-hoai-co-gia-17-trieu-dong-4681951.html', 'https://vnexpress.net/meta-bi-to-cao-lam-ngo-truoc-noi-dung-doc-hai-4682046.html', 'https://vnexpress.net/samsung-sap-ra-ai-phone-4681968.html', 'https://vnexpress.net/con-ba-ngay-ket-thuc-so-loai-tech-awards-2023-4681777.html', 'https://vnexpress.net/google-drive-gap-loi-la-gay-mat-du-lieu-4681957.html']
# Người dùng ngày càng chuộng iPhone bản đắt tiền https://vnexpress.net/nguoi-dung-ngay-cang-chuong-iphone-ban-dat-tien-4682179.html
# The post was successfully created.
# Response: {"success":false,"error_message":"B\u00e0i vi\u1ebft \u0111\u00e3 t\u1ed3n t\u1ea1i."}
# Tài khoản Google không hoạt động sẽ bị xóa từ cuối tuần https://vnexpress.net/tai-khoan-google-khong-hoat-dong-se-bi-xoa-tu-cuoi-tuan-4682171.html
# The post was successfully created.
# Response: {"success":false,"error_message":"B\u00e0i vi\u1ebft \u0111\u00e3 t\u1ed3n t\u1ea1i."}
# Kỹ sư ra lệnh - công việc sinh ra trong cơn sốt AI https://vnexpress.net/ky-su-ra-lenh-cong-viec-sinh-ra-trong-con-sot-ai-4681381.html
# The post was successfully created.
# Response: {"success":false,"error_message":"B\u00e0i vi\u1ebft \u0111\u00e3 t\u1ed3n t\u1ea1i."}
# CZ và Binance chưa thoát cáo buộc gian lận https://vnexpress.net/cz-va-binance-chua-thoat-cao-buoc-gian-lan-4682136.html
# The post was successfully created.
# Response: {"success":false,"error_message":"B\u00e0i vi\u1ebft \u0111\u00e3 t\u1ed3n t\u1ea1i."}
# JBL Authentics 500 - loa dáng hoài cổ giá 17 triệu đồng https://vnexpress.net/jbl-authentics-500-loa-dang-hoai-co-gia-17-trieu-dong-4681951.html
# The post was successfully created.
# Response: {"success":false,"error_message":"B\u00e0i vi\u1ebft \u0111\u00e3 t\u1ed3n t\u1ea1i."}
# Meta bị tố cáo làm ngơ trước nội dung độc hại https://vnexpress.net/meta-bi-to-cao-lam-ngo-truoc-noi-dung-doc-hai-4682046.html
# The post was successfully created.
# Response: {"success":false,"error_message":"B\u00e0i vi\u1ebft \u0111\u00e3 t\u1ed3n t\u1ea1i."}
# Samsung sắp ra 'AI Phone' https://vnexpress.net/samsung-sap-ra-ai-phone-4681968.html
# The post was successfully created.
# Response: {"success":false,"error_message":"B\u00e0i vi\u1ebft \u0111\u00e3 t\u1ed3n t\u1ea1i."}
# Còn ba ngày kết thúc Sơ loại Tech Awards 2023 https://vnexpress.net/con-ba-ngay-ket-thuc-so-loai-tech-awards-2023-4681777.html
# The post was successfully created.
# Response: {"success":false,"error_message":"B\u00e0i vi\u1ebft \u0111\u00e3 t\u1ed3n t\u1ea1i."}
# Google Drive gặp lỗi lạ gây mất dữ liệu https://vnexpress.net/google-drive-gap-loi-la-gay-mat-du-lieu-4681957.html
# The post was successfully created.
# Response: {"success":false,"error_message":"B\u00e0i vi\u1ebft \u0111\u00e3 t\u1ed3n t\u1ea1i."}

# %%
filter_list(get_list_url('https://vnexpress.net/rss/so-hoa.rss'))
# Out:
# ['https://vnexpress.net/nguoi-dung-ngay-cang-chuong-iphone-ban-dat-tien-4682179.html',
#  'https://vnexpress.net/tai-khoan-google-khong-hoat-dong-se-bi-xoa-tu-cuoi-tuan-4682171.html',
#  'https://vnexpress.net/ky-su-ra-lenh-cong-viec-sinh-ra-trong-con-sot-ai-4681381.html',
#  'https://vnexpress.net/cz-va-binance-chua-thoat-cao-buoc-gian-lan-4682136.html',
#  'https://vnexpress.net/jbl-authentics-500-loa-dang-hoai-co-gia-17-trieu-dong-4681951.html',
#  'https://vnexpress.net/meta-bi-to-cao-lam-ngo-truoc-noi-dung-doc-hai-4682046.html',
#  'https://vnexpress.net/samsung-sap-ra-ai-phone-4681968.html',
#  'https://vnexpress.net/con-ba-ngay-ket-thuc-so-loai-tech-awards-2023-4681777.html',
#  'https://vnexpress.net/google-drive-gap-loi-la-gay-mat-du-lieu-4681957.html']

# %%
test
# Out:
# {'home_page': 'https://vnexpress.net/',
#  'urls': {'Ô tô': {'url': 'https://vnexpress.net/#',
#    'sub-category': {0: {'name': 'Công nghệ',
#      'url': 'https://vnexpress.net/rss/so-hoa.rss',
#      'cate_id': 57,
#      'url_list': ['https://vnexpress.net/sieu-tri-tue-nhan-tao-agi-la-gi-4681761.html',
#       'https://vnexpress.net/hacker-danh-cap-47-trieu-usd-tu-kyber-nhu-the-nao-4681682.html',
#       'https://vnexpress.net/cong-nghe-sac-magsafe-se-co-mat-tren-android-nam-toi-4681543.html',
#       'https://vnexpress.net/nen-mua-may-giat-chung-hay-rieng-long-giat-say-4681701.html',
#       'https://vnexpress.net/tim-cook-ke-chuyen-tung-di-giao-bao-luc-rang-sang-4681540.html',
#       'https://vnexpress.net/bo-suu-tap-dien-thoai-di-dong-lon-nhat-the-gioi-4681523.html',
#       'https://vnexpress.net/bill-gates-con-nguoi-co-the-chi-lam-ba-ngay-moi-tuan-nho-ai-4681491.html',
#       'https://vnexpress.net/4-nam-fpt-camera-ho-tro-cong-nghe-giam-sat-cho-vnexpress-marathon-4681704.html'],
#      'content': {0: {'text': <article class="fck_detail"><strong class="" href="" id="" style="">Người đứng sau vụ hack nền tảng blockchain Việt Kyberswap yêu cầu có toàn bộ quyền kiểm soát công ty, đổi lại sẽ hoàn 50% số tiền đã lấy.</strong>
#        <p class="" href="" id="" style="">Một tuần sau khi tấn công vào KyberSwap Elastic, ngày 30/11, hacker đưa ra các điều kiện để hoàn số token tương đương 47 triệu USD đã đánh cắp. Người này đề nghị ban lãnh đạo công ty trao toàn quyền kiểm soát Kyber, quyền tạm thời với giao thức KyberDAO để thực hiện các thay đổi về bộ máy, mô hình quản trị.</p><p class="" href="" id="" style="">Hacker cũng muốn truy cập toàn bộ tài liệu, thông tin liên quan đến cấu trúc, hoạt động, doanh thu, lợi nhuận, tài sản, nợ phải trả, lương nhân viên, nhà đầu tư... của công ty.</p>
#        <figure class="" data-size="true" href="" id="" itemprop="associatedMedia image" itemscope="" itemtype="http://schema.org/ImageObject" style="">
#        <meta class="" content="https://vcdn-sohoa.vnecdn.net/2023/12/01/Kyber-jpeg-7997-1701418601.jpg?w=0&amp;h=0&amp;q=100&amp;dpr=2&amp;fit=crop&amp;s=VjEbSkPf6kK7XggiqGLARQ" href="" id="" itemprop="url" style=""/>
#        <meta class="" content="1200" href="" id="" itemprop="width" style=""/>
#        <meta class="" content="630" href="" id="" itemprop="height" style=""/>
#        <meta class="" content="" href="" id="" itemprop="href" style=""/>
#        <div class="" href="" id="" style=""><picture class="" href="" id="" style="">
#        <!--[if IE 9]><video style="display: none;"><![endif]-->
#        <source class="" data-srcset="https://vcdn-sohoa.vnecdn.net/2023/12/01/Kyber-jpeg-7997-1701418601.jpg?w=680&amp;h=0&amp;q=100&amp;dpr=1&amp;fit=crop&amp;s=YAD7hC6V4jsyp0SDFXdbuA 1x, https://vcdn-sohoa.vnecdn.net/2023/12/01/Kyber-jpeg-7997-1701418601.jpg?w=1020&amp;h=0&amp;q=100&amp;dpr=1&amp;fit=crop&amp;s=zaG30eSP-5m_N6wnRk6UkQ 1.5x, https://vcdn-sohoa.vnecdn.net/2023/12/01/Kyber-jpeg-7997-1701418601.jpg?w=680&amp;h=0&amp;q=100&amp;dpr=2&amp;fit=crop&amp;s=Y8QHCIH-RJz77L1-VOkK-g 2x" href="" id="" style=""/>
#        <!--[if IE 9]></video><![endif]-->
#        [caption id="" align="aligncenter" width="800"]<img alt="Minh họa với logo của KyberSwap. Ảnh: Coinmarketcap" class="aligncenter" height="400" href="" id="" src="..." style="" width="800"/>
#        Minh họa với logo của KyberSwap. Ảnh: Coinmarketcap
#        [/caption]
#        </picture></div>
#
#        </figure><p class="" href="" id="" style="">Bên tấn công cũng đòi Kyber nộp lại toàn bộ tài sản công ty, bao gồm cổ phiếu, vốn chủ sở hữu, token KNC và các token khác đang sở hữu. Thậm chí trang web, máy chủ, mật khẩu, mã, tài khoản mạng xã hội cũng nằm trong thỏa thuận.</p><p class="" href="" id="" style="">Đổi lại, hacker sẽ trả công ty số tiền đã lấy, trong khi ban lãnh đạo có thể mua lại Kyber với định giá phù hợp. Nhân viên chọn ở lại công ty sẽ được trả lương gấp đôi, còn nhân viên nghỉ việc được đền bù 12 tháng lương và hỗ trợ tìm việc với. "Những người đã gửi tiền vào nhóm thanh khoản của KyberSwap sẽ được hoàn trả 50% tài sản do những khoản lỗ liên quan đến biến động thị trường gần đây. Số tiền đó nhiều hơn những gì mọi người đáng được nhận", tin tặc viết.</p><p class="" href="" id="" style="">Hacker cho biết đây là lời đề nghị duy nhất, nếu không được đáp ứng trước ngày 10/12, thỏa thuận sẽ bị hủy.</p><p class="" href="" id="" style="">Đáp lại, CEO KyberNetwork Victor Tran, tuyên bố trên X ngày 30/11: "Không ai quan tâm đến người dùng Kyber như chúng tôi. Các bạn xứng đáng nhận được những gì tốt nhất. Thông điệp sẽ có vào ngày mai".</p><p class="" href="" id="" style="">Tuy nhiên, 19 giờ trôi qua, Kyber và các lãnh đạo công ty vẫn chưa đưa ra phản hồi thêm. Trong khi đó, tiểu sử trên X của Victor Tran có thêm dòng mô tả "just became a hunter" (mới thành thợ săn).</p><p class="" href="" id="" style="">Trước đó, trong thông báo đầu gửi đến hacker, đại diện Kyber cho biết sẽ tặng 10% số tiền nếu tin tặc trả lại token đánh cắp. CEO KyberSwap, cho biết nhóm đang nỗ lực lấy lại tiền và đưa hacker ra ánh sáng. Tuy nhiên, đến nay vẫn chưa có cam kết nào từ ban lãnh đạo Kyber về việc sẽ bồi thường cho người dùng.</p>
#        <figure class="" data-size="true" href="" id="" itemprop="associatedMedia image" itemscope="" itemtype="http://schema.org/ImageObject" style="">
#        <meta class="" content="https://vcdn-sohoa.vnecdn.net/2023/12/01/Screen-Shot-2023-12-01-at-15-0-4662-9275-1701418601.png?w=0&amp;h=0&amp;q=100&amp;dpr=2&amp;fit=crop&amp;s=CNmJg26tTmOHwZREPj2W5w" href="" id="" itemprop="url" style=""/>
#        <meta class="" content="1476" href="" id="" itemprop="width" style=""/>
#        <meta class="" content="740" href="" id="" itemprop="height" style=""/>
#        <meta class="" content="" href="" id="" itemprop="href" style=""/>
#        <div class="" href="" id="" style=""><picture class="" href="" id="" style="">
#        <!--[if IE 9]><video style="display: none;"><![endif]-->
#        <source class="" data-srcset="https://vcdn-sohoa.vnecdn.net/2023/12/01/Screen-Shot-2023-12-01-at-15-0-4662-9275-1701418601.png?w=680&amp;h=0&amp;q=100&amp;dpr=1&amp;fit=crop&amp;s=PuiXfSmBvLACCsGTdvk2iA 1x, https://vcdn-sohoa.vnecdn.net/2023/12/01/Screen-Shot-2023-12-01-at-15-0-4662-9275-1701418601.png?w=1020&amp;h=0&amp;q=100&amp;dpr=1&amp;fit=crop&amp;s=JJ2bXlXi4R5en09FOg630Q 1.5x, https://vcdn-sohoa.vnecdn.net/2023/12/01/Screen-Shot-2023-12-01-at-15-0-4662-9275-1701418601.png?w=680&amp;h=0&amp;q=100&amp;dpr=2&amp;fit=crop&amp;s=JN0x1ylUXeHEupmQbbBrAg 2x" href="" id="" style=""/>
#        <!--[if IE 9]></video><![endif]-->
#        [caption id="" align="aligncenter" width="800"]<img alt="Tổng tài sản người dùng gửi vào dự án của Kyber giảm từ 86 triệu USD (ngày 23/11) xuống còn 7,7 triệu USD ngày 1/12. Nguồn: DefiLlama" class="aligncenter" height="400" href="" id="" src="..." style="" width="800"/>
#        Tổng tài sản người dùng gửi vào dự án của Kyber giảm từ 86 triệu USD (ngày 23/11) xuống 7,7 triệu USD ngày 1/12. Nguồn: DefiLlama
#        [/caption]
#        </picture></div>
#
#        </figure><p class="" href="" id="" style=""><em class="" href="" id="" style="">BeInCrypto</em> đánh giá điều kiện hacker đưa ra "khá hài hước" nhưng đã phơi bày một thực tế đáng lo ngại về mô hình hoạt động của các sàn giao dịch phi tập trung. Bất chấp những tuyên bố về phân tán quyền lực, vụ tấn công và "hiệp ước" thương thảo cho thấy giao thức vẫn nằm trong tay một nhóm người. Đó là lý do hacker có thể tống tiền các giám đốc KyberSwap và đòi quyền kiểm soát.</p><p class="" href="" id="" style="">Trước đó ngày 23/11, tài khoản chính thức của Kyber Network thông báo trên X về việc KyberSwap Elastic gặp sự cố bảo mật và khuyến cáo người dùng nên rút tiền ngay lập tức. Tổng tài sản bị mất tương đương 47 triệu USD và tất cả được gửi vào một địa chỉ ví duy nhất.</p><p class="" href="" id="" style="">Kyber Network ra đời năm 2017 với ba nhà đồng sáng lập Lợi Lưu, Victor Tran và Yaron Velner. Đây là một trong những dự án blockchain đầu tiên do người Việt phát triển và thu hút sự chú ý lớn trên cộng đồng quốc tế. Dự án từng gọi vốn 52 triệu USD dưới hình thức ICO. Các sản phẩm chính của KyberNetwork là sàn giao dịch phi tập trung KyberSwap và nền tảng quản lý tài sản số Krystal.</p><p class="" href="" id="" style="">Dữ liệu từ <em class="" href="" id="" style="">DefiLlama</em> cho thấy tổng tài sản người dùng gửi vào dự án của Kyber giảm từ 86 triệu USD xuống còn 27 triệu USD sau thông tin KyberSwap Elastic bị tấn công được công bố. Đến 30/11, con số này giảm còn 7,17 triệu USD. Điều này cho thấy một đợt rút tiền khỏi nền tảng đã diễn ra ồ ạt.</p><div class="" data-component="true" data-component-type="tin_xemthem" data-component-value="4506948,4680243,4681682" data-thumb="1" href="" id="" style=""></div>
#        <!-- Hope -->
#        <!-- End Hope -->
#        <i>Nguồn: vnexpress.net</i></article>,
#        'title': 'Hacker đánh cắp 47 triệu USD của Kyber đòi quyền kiểm soát công ty',
#        'published_date': '2023-12-01'},
#       1: {'text': <article class="fck_detail"><strong class="" href="" id="" style="">Người đứng sau vụ hack nền tảng blockchain Việt Kyberswap yêu cầu có toàn bộ quyền kiểm soát công ty, đổi lại sẽ hoàn 50% số tiền đã lấy.</strong>
#        <p class="" href="" id="" style="">Một tuần sau khi tấn công vào KyberSwap Elastic, ngày 30/11, hacker đưa ra các điều kiện để hoàn số token tương đương 47 triệu USD đã đánh cắp. Người này đề nghị ban lãnh đạo công ty trao toàn quyền kiểm soát Kyber, quyền tạm thời với giao thức KyberDAO để thực hiện các thay đổi về bộ máy, mô hình quản trị.</p><p class="" href="" id="" style="">Hacker cũng muốn truy cập toàn bộ tài liệu, thông tin liên quan đến cấu trúc, hoạt động, doanh thu, lợi nhuận, tài sản, nợ phải trả, lương nhân viên, nhà đầu tư... của công ty.</p><figure class="" data-href="" data-target="" href="" id="" style=""><div class="" data-href="" data-target="" href="" id="" style="">[caption id="" align="aligncenter" width="800"]<img alt="Minh họa với logo của KyberSwap. Ảnh: Coinmarketcap" class="aligncenter" height="400" href="" id="" src="https://vcdn-sohoa.vnecdn.net/2023/12/01/Kyber-jpeg-7997-1701418601.jpg" style="" width="800"/>Minh họa với logo của KyberSwap. Ảnh: Coinmarketcap[/caption]</div></figure><p class="" href="" id="" style="">Bên tấn công cũng đòi Kyber nộp lại toàn bộ tài sản công ty, bao gồm cổ phiếu, vốn chủ sở hữu, token KNC và các token khác đang sở hữu. Thậm chí trang web, máy chủ, mật khẩu, mã, tài khoản mạng xã hội cũng nằm trong thỏa thuận.</p><p class="" href="" id="" style="">Đổi lại, hacker sẽ trả công ty số tiền đã lấy, trong khi ban lãnh đạo có thể mua lại Kyber với định giá phù hợp. Nhân viên chọn ở lại công ty sẽ được trả lương gấp đôi, còn nhân viên nghỉ việc được đền bù 12 tháng lương và hỗ trợ tìm việc với. "Những người đã gửi tiền vào nhóm thanh khoản của KyberSwap sẽ được hoàn trả 50% tài sản do những khoản lỗ liên quan đến biến động thị trường gần đây. Số tiền đó nhiều hơn những gì mọi người đáng được nhận", tin tặc viết.</p><p class="" href="" id="" style="">Hacker cho biết đây là lời đề nghị duy nhất, nếu không được đáp ứng trước ngày 10/12, thỏa thuận sẽ bị hủy.</p><p class="" href="" id="" style="">Đáp lại, CEO KyberNetwork Victor Tran, tuyên bố trên X ngày 30/11: "Không ai quan tâm đến người dùng Kyber như chúng tôi. Các bạn xứng đáng nhận được những gì tốt nhất. Thông điệp sẽ có vào ngày mai".</p><p class="" href="" id="" style="">Tuy nhiên, 19 giờ trôi qua, Kyber và các lãnh đạo công ty vẫn chưa đưa ra phản hồi thêm. Trong khi đó, tiểu sử trên X của Victor Tran có thêm dòng mô tả "just became a hunter" (mới thành thợ săn).</p><p class="" href="" id="" style="">Trước đó, trong thông báo đầu gửi đến hacker, đại diện Kyber cho biết sẽ tặng 10% số tiền nếu tin tặc trả lại token đánh cắp. CEO KyberSwap, cho biết nhóm đang nỗ lực lấy lại tiền và đưa hacker ra ánh sáng. Tuy nhiên, đến nay vẫn chưa có cam kết nào từ ban lãnh đạo Kyber về việc sẽ bồi thường cho người dùng.</p><figure class="" data-href="" data-target="" href="" id="" style=""><div class="" data-href="" data-target="" href="" id="" style="">[caption id="" align="aligncenter" width="800"]<img alt="Tổng tài sản người dùng gửi vào dự án của Kyber giảm từ 86 triệu USD (ngày 23/11) xuống còn 7,7 triệu USD ngày 1/12. Nguồn: DefiLlama" class="aligncenter" height="400" href="" id="" src="https://vcdn-sohoa.vnecdn.net/2023/12/01/Screen-Shot-2023-12-01-at-15-0-4662-9275-1701418601.png" style="" width="800"/>Tổng tài sản người dùng gửi vào dự án của Kyber giảm từ 86 triệu USD (ngày 23/11) xuống 7,7 triệu USD ngày 1/12. Nguồn: DefiLlama[/caption]</div></figure><p class="" href="" id="" style=""><em class="" href="" id="" style="">BeInCrypto</em> đánh giá điều kiện hacker đưa ra "khá hài hước" nhưng đã phơi bày một thực tế đáng lo ngại về mô hình hoạt động của các sàn giao dịch phi tập trung. Bất chấp những tuyên bố về phân tán quyền lực, vụ tấn công và "hiệp ước" thương thảo cho thấy giao thức vẫn nằm trong tay một nhóm người. Đó là lý do hacker có thể tống tiền các giám đốc KyberSwap và đòi quyền kiểm soát.</p><p class="" href="" id="" style="">Trước đó ngày 23/11, tài khoản chính thức của Kyber Network thông báo trên X về v ...
#        <!-- Hope -->
#        <!-- End Hope -->
#        <i>Nguồn: vnexpress.net</i></article>,
#        'title': 'Hacker đánh cắp 47 triệu USD của Kyber đòi quyền kiểm soát công ty',
#        'published_date': '2023-12-01'},
#       2: {'text': <article class="fck_detail"><strong class="" href="" id="" style="">Người đứng sau vụ hack nền tảng blockchain Việt Kyberswap yêu cầu có toàn bộ quyền kiểm soát công ty, đổi lại sẽ hoàn 50% số tiền đã lấy.</strong>
#        <p class="" href="" id="" style="">Một tuần sau khi tấn công vào KyberSwap Elastic, ngày 30/11, hacker đưa ra các điều kiện để hoàn số token tương đương 47 triệu USD đã đánh cắp. Người này đề nghị ban lãnh đạo công ty trao toàn quyền kiểm soát Kyber, quyền tạm thời với giao thức KyberDAO để thực hiện các thay đổi về bộ máy, mô hình quản trị.</p><p class="" href="" id="" style="">Hacker cũng muốn truy cập toàn bộ tài liệu, thông tin liên quan đến cấu trúc, hoạt động, doanh thu, lợi nhuận, tài sản, nợ phải trả, lương nhân viên, nhà đầu tư... của công ty.</p>
#        <figure class="" data-size="true" href="" id="" itemprop="associatedMedia image" itemscope="" itemtype="http://schema.org/ImageObject" style="">
#        <meta class="" content="https://vcdn-sohoa.vnecdn.net/2023/12/01/Kyber-jpeg-7997-1701418601.jpg?w=0&amp;h=0&amp;q=100&amp;dpr=2&amp;fit=crop&amp;s=VjEbSkPf6kK7XggiqGLARQ" href="" id="" itemprop="url" style=""/>
#        <meta class="" content="1200" href="" id="" itemprop="width" style=""/>
#        <meta class="" content="630" href="" id="" itemprop="height" style=""/>
#        <meta class="" content="" href="" id="" itemprop="href" style=""/>
#        <div class="" href="" id="" style=""><picture class="" href="" id="" style="">
#        <!--[if IE 9]><video style="display: none;"><![endif]-->
#        <source class="" data-srcset="https://vcdn-sohoa.vnecdn.net/2023/12/01/Kyber-jpeg-7997-1701418601.jpg?w=680&amp;h=0&amp;q=100&amp;dpr=1&amp;fit=crop&amp;s=YAD7hC6V4jsyp0SDFXdbuA 1x, https://vcdn-sohoa.vnecdn.net/2023/12/01/Kyber-jpeg-7997-1701418601.jpg?w=1020&amp;h=0&amp;q=100&amp;dpr=1&amp;fit=crop&amp;s=zaG30eSP-5m_N6wnRk6UkQ 1.5x, https://vcdn-sohoa.vnecdn.net/2023/12/01/Kyber-jpeg-7997-1701418601.jpg?w=680&amp;h=0&amp;q=100&amp;dpr=2&amp;fit=crop&amp;s=Y8QHCIH-RJz77L1-VOkK-g 2x" href="" id="" style=""/>
#        <!--[if IE 9]></video><![endif]-->
#        [caption id="" align="aligncenter" width="800"]<img alt="Minh họa với logo của KyberSwap. Ảnh: Coinmarketcap" class="aligncenter" height="400" href="" id="" src="..." style="" width="800"/>
#        Minh họa với logo của KyberSwap. Ảnh: Coinmarketcap
#        [/caption]
#        </picture></div>
#
#        </figure><p class="" href="" id="" style="">Bên tấn công cũng đòi Kyber nộp lại toàn bộ tài sản công ty, bao gồm cổ phiếu, vốn chủ sở hữu, token KNC và các token khác đang sở hữu. Thậm chí trang web, máy chủ, mật khẩu, mã, tài khoản mạng xã hội cũng nằm trong thỏa thuận.</p><p class="" href="" id="" style="">Đổi lại, hacker sẽ trả công ty số tiền đã lấy, trong khi ban lãnh đạo có thể mua lại Kyber với định giá phù hợp. Nhân viên chọn ở lại công ty sẽ được trả lương gấp đôi, còn nhân viên nghỉ việc được đền bù 12 tháng lương và hỗ trợ tìm việc với. "Những người đã gửi tiền vào nhóm thanh khoản của KyberSwap sẽ được hoàn trả 50% tài sản do những khoản lỗ liên quan đến biến động thị trường gần đây. Số tiền đó nhiều hơn những gì mọi người đáng được nhận", tin tặc viết.</p><p class="" href="" id="" style="">Hacker cho biết đây là lời đề nghị duy nhất, nếu không được đáp ứng trước ngày 10/12, thỏa thuận sẽ bị hủy.</p><p class="" href="" id="" style="">Đáp lại, CEO KyberNetwork Victor Tran, tuyên bố trên X ngày 30/11: "Không ai quan tâm đến người dùng Kyber như chúng tôi. Các bạn xứng đáng nhận được những gì tốt nhất. Thông điệp sẽ có vào ngày mai".</p><p class="" href="" id="" style="">Tuy nhiên, 19 giờ trôi qua, Kyber và các lãnh đạo công ty vẫn chưa đưa ra phản hồi thêm. Trong khi đó, tiểu sử trên X của Victor Tran có thêm dòng mô tả "just became a hunter" (mới thành thợ săn).</p><p class="" href="" id="" style="">Trước đó, trong thông báo đầu gửi đến hacker, đại diện Kyber cho biết sẽ tặng 10% số tiền nếu tin tặc trả lại token đánh cắp. CEO KyberSwap, cho biết nhóm đang nỗ lực lấy lại tiền và đưa hacker ra ánh sáng. Tuy nhiên, đến nay vẫn chưa có cam kết nào từ ban lãnh đạo Kyber về việc sẽ bồi thường cho người dùng.</p>
#        <figure class="" data-size="true" href="" id="" itemprop="associatedMedia image" itemscope="" itemtype="http://schema.org/ImageObject" style="">
#        <meta class="" content="https://vcdn-sohoa.vnecdn.net/2023/12/01/Screen-Shot-2023-12-01-at-15-0-4662-9275-1701418601.png?w=0&amp;h=0&amp;q=100&amp;dpr=2&amp;fit=crop&amp;s=CNmJg26tTmOHwZREPj2W5w" href="" id="" itemprop="url" style=""/>
#        <meta class="" content="1476" href="" id="" itemprop="width" style=""/>
#        <meta class="" content="740" href="" id="" itemprop="height" style=""/>
#        <meta class="" content="" href="" id="" itemprop="href" style=""/>
#        <div class="" href="" id="" style=""><picture class="" href="" id="" style="">
#        <!--[if IE 9]><video style="display: none;"><![endif]-->
#        <source class="" data-srcset="https://vcdn-sohoa.vnecdn.net/2023/12/01/Screen-Shot-2023-12-01-at-15-0-4662-9275-1701418601.png?w=680&amp;h=0&amp;q=100&amp;dpr=1&amp;fit=crop&amp;s=PuiXfSmBvLACCsGTdvk2iA 1x, https://vcdn-sohoa.vnecdn.net/2023/12/01/Screen-Shot-2023-12-01-at-15-0-4662-9275-1701418601.png?w=1020&amp;h=0&amp;q=100&amp;dpr=1&amp;fit=crop&amp;s=JJ2bXlXi4R5en09FOg630Q 1.5x, https://vcdn-sohoa.vnecdn.net/2023/12/01/Screen-Shot-2023-12-01-at-15-0-4662-9275-1701418601.png?w=680&amp;h=0&amp;q=100&amp;dpr=2&amp;fit=crop&amp;s=JN0x1ylUXeHEupmQbbBrAg 2x" href="" id="" style=""/>
#        <!--[if IE 9]></video><![endif]-->
#        [caption id="" align="aligncenter" width="800"]<img alt="Tổng tài sản người dùng gửi vào dự án của Kyber giảm từ 86 triệu USD (ngày 23/11) xuống còn 7,7 triệu USD ngày 1/12. Nguồn: DefiLlama" class="aligncenter" height="400" href="" id="" src="..." style="" width="800"/>
#        Tổng tài sản người dùng gửi vào dự án của Kyber giảm từ 86 triệu USD (ngày 23/11) xuống 7,7 triệu USD ngày 1/12. Nguồn: DefiLlama
#        [/caption]
#        </picture></div>
#
#        </figure><p class="" href="" id="" style=""><em class="" href="" id="" style="">BeInCrypto</em> đánh giá điều kiện hacker đưa ra "khá hài hước" nhưng đã phơi bày một thực tế đáng lo ngại về mô hình hoạt động của các sàn giao dịch phi tập trung. Bất chấp những tuyên bố về phân tán quyền lực, vụ tấn công và "hiệp ước" thương thảo cho thấy giao thức vẫn nằm trong tay một nhóm người. Đó là lý do hacker có thể tống tiền các giám đốc KyberSwap và đòi quyền kiểm soát.</p><p class="" href="" id="" style="">Trước đó ngày 23/11, tài khoản chính thức của Kyber Network thông báo trên X về việc KyberSwap Elastic gặp sự cố bảo mật và khuyến cáo người dùng nên rút tiền ngay lập tức. Tổng tài sản bị mất tương đương 47 triệu USD và tất cả được gửi vào một địa chỉ ví duy nhất.</p><p class="" href="" id="" style="">Kyber Network ra đời năm 2017 với ba nhà đồng sáng lập Lợi Lưu, Victor Tran và Yaron Velner. Đây là một trong những dự án blockchain đầu tiên do người Việt phát triển và thu hút sự chú ý lớn trên cộng đồng quốc tế. Dự án từng gọi vốn 52 triệu USD dưới hình thức ICO. Các sản phẩm chính của KyberNetwork là sàn giao dịch phi tập trung KyberSwap và nền tảng quản lý tài sản số Krystal.</p><p class="" href="" id="" style="">Dữ liệu từ <em class="" href="" id="" style="">DefiLlama</em> cho thấy tổng tài sản người dùng gửi vào dự án của Kyber giảm từ 86 triệu USD xuống còn 27 triệu USD sau thông tin KyberSwap Elastic bị tấn công được công bố. Đến 30/11, con số này giảm còn 7,17 triệu USD. Điều này cho thấy một đợt rút tiền khỏi nền tảng đã diễn ra ồ ạt.</p><div class="" data-component="true" data-component-type="tin_xemthem" data-component-value="4506948,4680243,4681682" data-thumb="1" href="" id="" style=""></div>
#        <!-- Hope -->
#        <!-- End Hope -->
#        <i>Nguồn: vnexpress.net</i></article>,
#        'title': 'Hacker đánh cắp 47 triệu USD của Kyber đòi quyền kiểm soát công ty',
#        'published_date': '2023-12-01'},
#       3: {'text': <article class="fck_detail"><strong class="" href="" id="" style="">Người đứng sau vụ hack nền tảng blockchain Việt Kyberswap yêu cầu có toàn bộ quyền kiểm soát công ty, đổi lại sẽ hoàn 50% số tiền đã lấy.</strong>
#        <p class="" href="" id="" style="">Một tuần sau khi tấn công vào KyberSwap Elastic, ngày 30/11, hacker đưa ra các điều kiện để hoàn số token tương đương 47 triệu USD đã đánh cắp. Người này đề nghị ban lãnh đạo công ty trao toàn quyền kiểm soát Kyber, quyền tạm thời với giao thức KyberDAO để thực hiện các thay đổi về bộ máy, mô hình quản trị.</p><p class="" href="" id="" style="">Hacker cũng muốn truy cập toàn bộ tài liệu, thông tin liên quan đến cấu trúc, hoạt động, doanh thu, lợi nhuận, tài sản, nợ phải trả, lương nhân viên, nhà đầu tư... của công ty.</p><figure class="" data-href="" data-target="" href="" id="" style=""><div class="" data-href="" data-target="" href="" id="" style="">[caption id="" align="aligncenter" width="800"]<img alt="Minh họa với logo của KyberSwap. Ảnh: Coinmarketcap" class="aligncenter" height="400" href="" id="" src="https://vcdn-sohoa.vnecdn.net/2023/12/01/Kyber-jpeg-7997-1701418601.jpg" style="" width="800"/>Minh họa với logo của KyberSwap. Ảnh: Coinmarketcap[/caption]</div></figure><p class="" href="" id="" style="">Bên tấn công cũng đòi Kyber nộp lại toàn bộ tài sản công ty, bao gồm cổ phiếu, vốn chủ sở hữu, token KNC và các token khác đang sở hữu. Thậm chí trang web, máy chủ, mật khẩu, mã, tài khoản mạng xã hội cũng nằm trong thỏa thuận.</p><p class="" href="" id="" style="">Đổi lại, hacker sẽ trả công ty số tiền đã lấy, trong khi ban lãnh đạo có thể mua lại Kyber với định giá phù hợp. Nhân viên chọn ở lại công ty sẽ được trả lương gấp đôi, còn nhân viên nghỉ việc được đền bù 12 tháng lương và hỗ trợ tìm việc với. "Những người đã gửi tiền vào nhóm thanh khoản của KyberSwap sẽ được hoàn trả 50% tài sản do những khoản lỗ liên quan đến biến động thị trường gần đây. Số tiền đó nhiều hơn những gì mọi người đáng được nhận", tin tặc viết.</p><p class="" href="" id="" style="">Hacker cho biết đây là lời đề nghị duy nhất, nếu không được đáp ứng trước ngày 10/12, thỏa thuận sẽ bị hủy.</p><p class="" href="" id="" style="">Đáp lại, CEO KyberNetwork Victor Tran, tuyên bố trên X ngày 30/11: "Không ai quan tâm đến người dùng Kyber như chúng tôi. Các bạn xứng đáng nhận được những gì tốt nhất. Thông điệp sẽ có vào ngày mai".</p><p class="" href="" id="" style="">Tuy nhiên, 19 giờ trôi qua, Kyber và các lãnh đạo công ty vẫn chưa đưa ra phản hồi thêm. Trong khi đó, tiểu sử trên X của Victor Tran có thêm dòng mô tả "just became a hunter" (mới thành thợ săn).</p><p class="" href="" id="" style="">Trước đó, trong thông báo đầu gửi đến hacker, đại diện Kyber cho biết sẽ tặng 10% số tiền nếu tin tặc trả lại token đánh cắp. CEO KyberSwap, cho biết nhóm đang nỗ lực lấy lại tiền và đưa hacker ra ánh sáng. Tuy nhiên, đến nay vẫn chưa có cam kết nào từ ban lãnh đạo Kyber về việc sẽ bồi thường cho người dùng.</p><figure class="" data-href="" data-target="" href="" id="" style=""><div class="" data-href="" data-target="" href="" id="" style="">[caption id="" align="aligncenter" width="800"]<img alt="Tổng tài sản người dùng gửi vào dự án của Kyber giảm từ 86 triệu USD (ngày 23/11) xuống còn 7,7 triệu USD ngày 1/12. Nguồn: DefiLlama" class="aligncenter" height="400" href="" id="" src="https://vcdn-sohoa.vnecdn.net/2023/12/01/Screen-Shot-2023-12-01-at-15-0-4662-9275-1701418601.png" style="" width="800"/>Tổng tài sản người dùng gửi vào dự án của Kyber giảm từ 86 triệu USD (ngày 23/11) xuống 7,7 triệu USD ngày 1/12. Nguồn: DefiLlama[/caption]</div></figure><p class="" href="" id="" style=""><em class="" href="" id="" style="">BeInCrypto</em> đánh giá điều kiện hacker đưa ra "khá hài hước" nhưng đã phơi bày một thực tế đáng lo ngại về mô hình hoạt động của các sàn giao dịch phi tập trung. Bất chấp những tuyên bố về phân tán quyền lực, vụ tấn công và "hiệp ước" thương thảo cho thấy giao thức vẫn nằm trong tay một nhóm người. Đó là lý do hacker có thể tống tiền các giám đốc KyberSwap và đòi quyền kiểm soát.</p><p class="" href="" id="" style="">Trước đó ngày 23/11, tài khoản chính thức của Kyber Network thông báo trên X về v ...
#        <!-- Hope -->
#        <!-- End Hope -->
#        <i>Nguồn: vnexpress.net</i></article>,
#        'title': 'Hacker đánh cắp 47 triệu USD của Kyber đòi quyền kiểm soát công ty',
#        'published_date': '2023-12-01'},
#       4: {'text': <article class="fck_detail"><strong class="" href="" id="" style="">Người đứng sau vụ hack nền tảng blockchain Việt Kyberswap yêu cầu có toàn bộ quyền kiểm soát công ty, đổi lại sẽ hoàn 50% số tiền đã lấy.</strong>
#        <p class="" href="" id="" style="">Một tuần sau khi tấn công vào KyberSwap Elastic, ngày 30/11, hacker đưa ra các điều kiện để hoàn số token tương đương 47 triệu USD đã đánh cắp. Người này đề nghị ban lãnh đạo công ty trao toàn quyền kiểm soát Kyber, quyền tạm thời với giao thức KyberDAO để thực hiện các thay đổi về bộ máy, mô hình quản trị.</p><p class="" href="" id="" style="">Hacker cũng muốn truy cập toàn bộ tài liệu, thông tin liên quan đến cấu trúc, hoạt động, doanh thu, lợi nhuận, tài sản, nợ phải trả, lương nhân viên, nhà đầu tư... của công ty.</p>
#        <figure class="" data-size="true" href="" id="" itemprop="associatedMedia image" itemscope="" itemtype="http://schema.org/ImageObject" style="">
#        <meta class="" content="https://vcdn-sohoa.vnecdn.net/2023/12/01/Kyber-jpeg-7997-1701418601.jpg?w=0&amp;h=0&amp;q=100&amp;dpr=2&amp;fit=crop&amp;s=VjEbSkPf6kK7XggiqGLARQ" href="" id="" itemprop="url" style=""/>
#        <meta class="" content="1200" href="" id="" itemprop="width" style=""/>
#        <meta class="" content="630" href="" id="" itemprop="height" style=""/>
#        <meta class="" content="" href="" id="" itemprop="href" style=""/>
#        <div class="" href="" id="" style=""><picture class="" href="" id="" style="">
#        <!--[if IE 9]><video style="display: none;"><![endif]-->
#        <source class="" data-srcset="https://vcdn-sohoa.vnecdn.net/2023/12/01/Kyber-jpeg-7997-1701418601.jpg?w=680&amp;h=0&amp;q=100&amp;dpr=1&amp;fit=crop&amp;s=YAD7hC6V4jsyp0SDFXdbuA 1x, https://vcdn-sohoa.vnecdn.net/2023/12/01/Kyber-jpeg-7997-1701418601.jpg?w=1020&amp;h=0&amp;q=100&amp;dpr=1&amp;fit=crop&amp;s=zaG30eSP-5m_N6wnRk6UkQ 1.5x, https://vcdn-sohoa.vnecdn.net/2023/12/01/Kyber-jpeg-7997-1701418601.jpg?w=680&amp;h=0&amp;q=100&amp;dpr=2&amp;fit=crop&amp;s=Y8QHCIH-RJz77L1-VOkK-g 2x" href="" id="" style=""/>
#        <!--[if IE 9]></video><![endif]-->
#        [caption id="" align="aligncenter" width="800"]<img alt="Minh họa với logo của KyberSwap. Ảnh: Coinmarketcap" class="aligncenter" height="400" href="" id="" src="..." style="" width="800"/>
#        Minh họa với logo của KyberSwap. Ảnh: Coinmarketcap
#        [/caption]
#        </picture></div>
#
#        </figure><p class="" href="" id="" style="">Bên tấn công cũng đòi Kyber nộp lại toàn bộ tài sản công ty, bao gồm cổ phiếu, vốn chủ sở hữu, token KNC và các token khác đang sở hữu. Thậm chí trang web, máy chủ, mật khẩu, mã, tài khoản mạng xã hội cũng nằm trong thỏa thuận.</p><p class="" href="" id="" style="">Đổi lại, hacker sẽ trả công ty số tiền đã lấy, trong khi ban lãnh đạo có thể mua lại Kyber với định giá phù hợp. Nhân viên chọn ở lại công ty sẽ được trả lương gấp đôi, còn nhân viên nghỉ việc được đền bù 12 tháng lương và hỗ trợ tìm việc với. "Những người đã gửi tiền vào nhóm thanh khoản của KyberSwap sẽ được hoàn trả 50% tài sản do những khoản lỗ liên quan đến biến động thị trường gần đây. Số tiền đó nhiều hơn những gì mọi người đáng được nhận", tin tặc viết.</p><p class="" href="" id="" style="">Hacker cho biết đây là lời đề nghị duy nhất, nếu không được đáp ứng trước ngày 10/12, thỏa thuận sẽ bị hủy.</p><p class="" href="" id="" style="">Đáp lại, CEO KyberNetwork Victor Tran, tuyên bố trên X ngày 30/11: "Không ai quan tâm đến người dùng Kyber như chúng tôi. Các bạn xứng đáng nhận được những gì tốt nhất. Thông điệp sẽ có vào ngày mai".</p><p class="" href="" id="" style="">Tuy nhiên, 19 giờ trôi qua, Kyber và các lãnh đạo công ty vẫn chưa đưa ra phản hồi thêm. Trong khi đó, tiểu sử trên X của Victor Tran có thêm dòng mô tả "just became a hunter" (mới thành thợ săn).</p><p class="" href="" id="" style="">Trước đó, trong thông báo đầu gửi đến hacker, đại diện Kyber cho biết sẽ tặng 10% số tiền nếu tin tặc trả lại token đánh cắp. CEO KyberSwap, cho biết nhóm đang nỗ lực lấy lại tiền và đưa hacker ra ánh sáng. Tuy nhiên, đến nay vẫn chưa có cam kết nào từ ban lãnh đạo Kyber về việc sẽ bồi thường cho người dùng.</p>
#        <figure class="" data-size="true" href="" id="" itemprop="associatedMedia image" itemscope="" itemtype="http://schema.org/ImageObject" style="">
#        <meta class="" content="https://vcdn-sohoa.vnecdn.net/2023/12/01/Screen-Shot-2023-12-01-at-15-0-4662-9275-1701418601.png?w=0&amp;h=0&amp;q=100&amp;dpr=2&amp;fit=crop&amp;s=CNmJg26tTmOHwZREPj2W5w" href="" id="" itemprop="url" style=""/>
#        <meta class="" content="1476" href="" id="" itemprop="width" style=""/>
#        <meta class="" content="740" href="" id="" itemprop="height" style=""/>
#        <meta class="" content="" href="" id="" itemprop="href" style=""/>
#        <div class="" href="" id="" style=""><picture class="" href="" id="" style="">
#        <!--[if IE 9]><video style="display: none;"><![endif]-->
#        <source class="" data-srcset="https://vcdn-sohoa.vnecdn.net/2023/12/01/Screen-Shot-2023-12-01-at-15-0-4662-9275-1701418601.png?w=680&amp;h=0&amp;q=100&amp;dpr=1&amp;fit=crop&amp;s=PuiXfSmBvLACCsGTdvk2iA 1x, https://vcdn-sohoa.vnecdn.net/2023/12/01/Screen-Shot-2023-12-01-at-15-0-4662-9275-1701418601.png?w=1020&amp;h=0&amp;q=100&amp;dpr=1&amp;fit=crop&amp;s=JJ2bXlXi4R5en09FOg630Q 1.5x, https://vcdn-sohoa.vnecdn.net/2023/12/01/Screen-Shot-2023-12-01-at-15-0-4662-9275-1701418601.png?w=680&amp;h=0&amp;q=100&amp;dpr=2&amp;fit=crop&amp;s=JN0x1ylUXeHEupmQbbBrAg 2x" href="" id="" style=""/>
#        <!--[if IE 9]></video><![endif]-->
#        [caption id="" align="aligncenter" width="800"]<img alt="Tổng tài sản người dùng gửi vào dự án của Kyber giảm từ 86 triệu USD (ngày 23/11) xuống còn 7,7 triệu USD ngày 1/12. Nguồn: DefiLlama" class="aligncenter" height="400" href="" id="" src="..." style="" width="800"/>
#        Tổng tài sản người dùng gửi vào dự án của Kyber giảm từ 86 triệu USD (ngày 23/11) xuống 7,7 triệu USD ngày 1/12. Nguồn: DefiLlama
#        [/caption]
#        </picture></div>
#
#        </figure><p class="" href="" id="" style=""><em class="" href="" id="" style="">BeInCrypto</em> đánh giá điều kiện hacker đưa ra "khá hài hước" nhưng đã phơi bày một thực tế đáng lo ngại về mô hình hoạt động của các sàn giao dịch phi tập trung. Bất chấp những tuyên bố về phân tán quyền lực, vụ tấn công và "hiệp ước" thương thảo cho thấy giao thức vẫn nằm trong tay một nhóm người. Đó là lý do hacker có thể tống tiền các giám đốc KyberSwap và đòi quyền kiểm soát.</p><p class="" href="" id="" style="">Trước đó ngày 23/11, tài khoản chính thức của Kyber Network thông báo trên X về việc KyberSwap Elastic gặp sự cố bảo mật và khuyến cáo người dùng nên rút tiền ngay lập tức. Tổng tài sản bị mất tương đương 47 triệu USD và tất cả được gửi vào một địa chỉ ví duy nhất.</p><p class="" href="" id="" style="">Kyber Network ra đời năm 2017 với ba nhà đồng sáng lập Lợi Lưu, Victor Tran và Yaron Velner. Đây là một trong những dự án blockchain đầu tiên do người Việt phát triển và thu hút sự chú ý lớn trên cộng đồng quốc tế. Dự án từng gọi vốn 52 triệu USD dưới hình thức ICO. Các sản phẩm chính của KyberNetwork là sàn giao dịch phi tập trung KyberSwap và nền tảng quản lý tài sản số Krystal.</p><p class="" href="" id="" style="">Dữ liệu từ <em class="" href="" id="" style="">DefiLlama</em> cho thấy tổng tài sản người dùng gửi vào dự án của Kyber giảm từ 86 triệu USD xuống còn 27 triệu USD sau thông tin KyberSwap Elastic bị tấn công được công bố. Đến 30/11, con số này giảm còn 7,17 triệu USD. Điều này cho thấy một đợt rút tiền khỏi nền tảng đã diễn ra ồ ạt.</p><div class="" data-component="true" data-component-type="tin_xemthem" data-component-value="4506948,4680243,4681682" data-thumb="1" href="" id="" style=""></div>
#        <!-- Hope -->
#        <!-- End Hope -->
#        <i>Nguồn: vnexpress.net</i></article>,
#        'title': 'Hacker đánh cắp 47 triệu USD của Kyber đòi quyền kiểm soát công ty',
#        'published_date': '2023-12-01'},
#       5: {'text': <article class="fck_detail"><strong class="" href="" id="" style="">Người đứng sau vụ hack nền tảng blockchain Việt Kyberswap yêu cầu có toàn bộ quyền kiểm soát công ty, đổi lại sẽ hoàn 50% số tiền đã lấy.</strong>
#        <p class="" href="" id="" style="">Một tuần sau khi tấn công vào KyberSwap Elastic, ngày 30/11, hacker đưa ra các điều kiện để hoàn số token tương đương 47 triệu USD đã đánh cắp. Người này đề nghị ban lãnh đạo công ty trao toàn quyền kiểm soát Kyber, quyền tạm thời với giao thức KyberDAO để thực hiện các thay đổi về bộ máy, mô hình quản trị.</p><p class="" href="" id="" style="">Hacker cũng muốn truy cập toàn bộ tài liệu, thông tin liên quan đến cấu trúc, hoạt động, doanh thu, lợi nhuận, tài sản, nợ phải trả, lương nhân viên, nhà đầu tư... của công ty.</p><figure class="" data-href="" data-target="" href="" id="" style=""><div class="" data-href="" data-target="" href="" id="" style="">[caption id="" align="aligncenter" width="800"]<img alt="Minh họa với logo của KyberSwap. Ảnh: Coinmarketcap" class="aligncenter" height="400" href="" id="" src="https://vcdn-sohoa.vnecdn.net/2023/12/01/Kyber-jpeg-7997-1701418601.jpg" style="" width="800"/>Minh họa với logo của KyberSwap. Ảnh: Coinmarketcap[/caption]</div></figure><p class="" href="" id="" style="">Bên tấn công cũng đòi Kyber nộp lại toàn bộ tài sản công ty, bao gồm cổ phiếu, vốn chủ sở hữu, token KNC và các token khác đang sở hữu. Thậm chí trang web, máy chủ, mật khẩu, mã, tài khoản mạng xã hội cũng nằm trong thỏa thuận.</p><p class="" href="" id="" style="">Đổi lại, hacker sẽ trả công ty số tiền đã lấy, trong khi ban lãnh đạo có thể mua lại Kyber với định giá phù hợp. Nhân viên chọn ở lại công ty sẽ được trả lương gấp đôi, còn nhân viên nghỉ việc được đền bù 12 tháng lương và hỗ trợ tìm việc với. "Những người đã gửi tiền vào nhóm thanh khoản của KyberSwap sẽ được hoàn trả 50% tài sản do những khoản lỗ liên quan đến biến động thị trường gần đây. Số tiền đó nhiều hơn những gì mọi người đáng được nhận", tin tặc viết.</p><p class="" href="" id="" style="">Hacker cho biết đây là lời đề nghị duy nhất, nếu không được đáp ứng trước ngày 10/12, thỏa thuận sẽ bị hủy.</p><p class="" href="" id="" style="">Đáp lại, CEO KyberNetwork Victor Tran, tuyên bố trên X ngày 30/11: "Không ai quan tâm đến người dùng Kyber như chúng tôi. Các bạn xứng đáng nhận được những gì tốt nhất. Thông điệp sẽ có vào ngày mai".</p><p class="" href="" id="" style="">Tuy nhiên, 19 giờ trôi qua, Kyber và các lãnh đạo công ty vẫn chưa đưa ra phản hồi thêm. Trong khi đó, tiểu sử trên X của Victor Tran có thêm dòng mô tả "just became a hunter" (mới thành thợ săn).</p><p class="" href="" id="" style="">Trước đó, trong thông báo đầu gửi đến hacker, đại diện Kyber cho biết sẽ tặng 10% số tiền nếu tin tặc trả lại token đánh cắp. CEO KyberSwap, cho biết nhóm đang nỗ lực lấy lại tiền và đưa hacker ra ánh sáng. Tuy nhiên, đến nay vẫn chưa có cam kết nào từ ban lãnh đạo Kyber về việc sẽ bồi thường cho người dùng.</p><figure class="" data-href="" data-target="" href="" id="" style=""><div class="" data-href="" data-target="" href="" id="" style="">[caption id="" align="aligncenter" width="800"]<img alt="Tổng tài sản người dùng gửi vào dự án của Kyber giảm từ 86 triệu USD (ngày 23/11) xuống còn 7,7 triệu USD ngày 1/12. Nguồn: DefiLlama" class="aligncenter" height="400" href="" id="" src="https://vcdn-sohoa.vnecdn.net/2023/12/01/Screen-Shot-2023-12-01-at-15-0-4662-9275-1701418601.png" style="" width="800"/>Tổng tài sản người dùng gửi vào dự án của Kyber giảm từ 86 triệu USD (ngày 23/11) xuống 7,7 triệu USD ngày 1/12. Nguồn: DefiLlama[/caption]</div></figure><p class="" href="" id="" style=""><em class="" href="" id="" style="">BeInCrypto</em> đánh giá điều kiện hacker đưa ra "khá hài hước" nhưng đã phơi bày một thực tế đáng lo ngại về mô hình hoạt động của các sàn giao dịch phi tập trung. Bất chấp những tuyên bố về phân tán quyền lực, vụ tấn công và "hiệp ước" thương thảo cho thấy giao thức vẫn nằm trong tay một nhóm người. Đó là lý do hacker có thể tống tiền các giám đốc KyberSwap và đòi quyền kiểm soát.</p><p class="" href="" id="" style="">Trước đó ngày 23/11, tài khoản chính thức của Kyber Network thông báo trên X về v ...
#        <!-- Hope -->
#        <!-- End Hope -->
#        <i>Nguồn: vnexpress.net</i></article>,
#        'title': 'Hacker đánh cắp 47 triệu USD của Kyber đòi quyền kiểm soát công ty',
#        'published_date': '2023-12-01'},
#       6: {'text': <article class="fck_detail"><strong class="" href="" id="" style="">Người đứng sau vụ hack nền tảng blockchain Việt Kyberswap yêu cầu có toàn bộ quyền kiểm soát công ty, đổi lại sẽ hoàn 50% số tiền đã lấy.</strong>
#        <p class="" href="" id="" style="">Một tuần sau khi tấn công vào KyberSwap Elastic, ngày 30/11, hacker đưa ra các điều kiện để hoàn số token tương đương 47 triệu USD đã đánh cắp. Người này đề nghị ban lãnh đạo công ty trao toàn quyền kiểm soát Kyber, quyền tạm thời với giao thức KyberDAO để thực hiện các thay đổi về bộ máy, mô hình quản trị.</p><p class="" href="" id="" style="">Hacker cũng muốn truy cập toàn bộ tài liệu, thông tin liên quan đến cấu trúc, hoạt động, doanh thu, lợi nhuận, tài sản, nợ phải trả, lương nhân viên, nhà đầu tư... của công ty.</p>
#        <figure class="" data-size="true" href="" id="" itemprop="associatedMedia image" itemscope="" itemtype="http://schema.org/ImageObject" style="">
#        <meta class="" content="https://vcdn-sohoa.vnecdn.net/2023/12/01/Kyber-jpeg-7997-1701418601.jpg?w=0&amp;h=0&amp;q=100&amp;dpr=2&amp;fit=crop&amp;s=VjEbSkPf6kK7XggiqGLARQ" href="" id="" itemprop="url" style=""/>
#        <meta class="" content="1200" href="" id="" itemprop="width" style=""/>
#        <meta class="" content="630" href="" id="" itemprop="height" style=""/>
#        <meta class="" content="" href="" id="" itemprop="href" style=""/>
#        <div class="" href="" id="" style=""><picture class="" href="" id="" style="">
#        <!--[if IE 9]><video style="display: none;"><![endif]-->
#        <source class="" data-srcset="https://vcdn-sohoa.vnecdn.net/2023/12/01/Kyber-jpeg-7997-1701418601.jpg?w=680&amp;h=0&amp;q=100&amp;dpr=1&amp;fit=crop&amp;s=YAD7hC6V4jsyp0SDFXdbuA 1x, https://vcdn-sohoa.vnecdn.net/2023/12/01/Kyber-jpeg-7997-1701418601.jpg?w=1020&amp;h=0&amp;q=100&amp;dpr=1&amp;fit=crop&amp;s=zaG30eSP-5m_N6wnRk6UkQ 1.5x, https://vcdn-sohoa.vnecdn.net/2023/12/01/Kyber-jpeg-7997-1701418601.jpg?w=680&amp;h=0&amp;q=100&amp;dpr=2&amp;fit=crop&amp;s=Y8QHCIH-RJz77L1-VOkK-g 2x" href="" id="" style=""/>
#        <!--[if IE 9]></video><![endif]-->
#        [caption id="" align="aligncenter" width="800"]<img alt="Minh họa với logo của KyberSwap. Ảnh: Coinmarketcap" class="aligncenter" height="400" href="" id="" src="..." style="" width="800"/>
#        Minh họa với logo của KyberSwap. Ảnh: Coinmarketcap
#        [/caption]
#        </picture></div>
#
#        </figure><p class="" href="" id="" style="">Bên tấn công cũng đòi Kyber nộp lại toàn bộ tài sản công ty, bao gồm cổ phiếu, vốn chủ sở hữu, token KNC và các token khác đang sở hữu. Thậm chí trang web, máy chủ, mật khẩu, mã, tài khoản mạng xã hội cũng nằm trong thỏa thuận.</p><p class="" href="" id="" style="">Đổi lại, hacker sẽ trả công ty số tiền đã lấy, trong khi ban lãnh đạo có thể mua lại Kyber với định giá phù hợp. Nhân viên chọn ở lại công ty sẽ được trả lương gấp đôi, còn nhân viên nghỉ việc được đền bù 12 tháng lương và hỗ trợ tìm việc với. "Những người đã gửi tiền vào nhóm thanh khoản của KyberSwap sẽ được hoàn trả 50% tài sản do những khoản lỗ liên quan đến biến động thị trường gần đây. Số tiền đó nhiều hơn những gì mọi người đáng được nhận", tin tặc viết.</p><p class="" href="" id="" style="">Hacker cho biết đây là lời đề nghị duy nhất, nếu không được đáp ứng trước ngày 10/12, thỏa thuận sẽ bị hủy.</p><p class="" href="" id="" style="">Đáp lại, CEO KyberNetwork Victor Tran, tuyên bố trên X ngày 30/11: "Không ai quan tâm đến người dùng Kyber như chúng tôi. Các bạn xứng đáng nhận được những gì tốt nhất. Thông điệp sẽ có vào ngày mai".</p><p class="" href="" id="" style="">Tuy nhiên, 19 giờ trôi qua, Kyber và các lãnh đạo công ty vẫn chưa đưa ra phản hồi thêm. Trong khi đó, tiểu sử trên X của Victor Tran có thêm dòng mô tả "just became a hunter" (mới thành thợ săn).</p><p class="" href="" id="" style="">Trước đó, trong thông báo đầu gửi đến hacker, đại diện Kyber cho biết sẽ tặng 10% số tiền nếu tin tặc trả lại token đánh cắp. CEO KyberSwap, cho biết nhóm đang nỗ lực lấy lại tiền và đưa hacker ra ánh sáng. Tuy nhiên, đến nay vẫn chưa có cam kết nào từ ban lãnh đạo Kyber về việc sẽ bồi thường cho người dùng.</p>
#        <figure class="" data-size="true" href="" id="" itemprop="associatedMedia image" itemscope="" itemtype="http://schema.org/ImageObject" style="">
#        <meta class="" content="https://vcdn-sohoa.vnecdn.net/2023/12/01/Screen-Shot-2023-12-01-at-15-0-4662-9275-1701418601.png?w=0&amp;h=0&amp;q=100&amp;dpr=2&amp;fit=crop&amp;s=CNmJg26tTmOHwZREPj2W5w" href="" id="" itemprop="url" style=""/>
#        <meta class="" content="1476" href="" id="" itemprop="width" style=""/>
#        <meta class="" content="740" href="" id="" itemprop="height" style=""/>
#        <meta class="" content="" href="" id="" itemprop="href" style=""/>
#        <div class="" href="" id="" style=""><picture class="" href="" id="" style="">
#        <!--[if IE 9]><video style="display: none;"><![endif]-->
#        <source class="" data-srcset="https://vcdn-sohoa.vnecdn.net/2023/12/01/Screen-Shot-2023-12-01-at-15-0-4662-9275-1701418601.png?w=680&amp;h=0&amp;q=100&amp;dpr=1&amp;fit=crop&amp;s=PuiXfSmBvLACCsGTdvk2iA 1x, https://vcdn-sohoa.vnecdn.net/2023/12/01/Screen-Shot-2023-12-01-at-15-0-4662-9275-1701418601.png?w=1020&amp;h=0&amp;q=100&amp;dpr=1&amp;fit=crop&amp;s=JJ2bXlXi4R5en09FOg630Q 1.5x, https://vcdn-sohoa.vnecdn.net/2023/12/01/Screen-Shot-2023-12-01-at-15-0-4662-9275-1701418601.png?w=680&amp;h=0&amp;q=100&amp;dpr=2&amp;fit=crop&amp;s=JN0x1ylUXeHEupmQbbBrAg 2x" href="" id="" style=""/>
#        <!--[if IE 9]></video><![endif]-->
#        [caption id="" align="aligncenter" width="800"]<img alt="Tổng tài sản người dùng gửi vào dự án của Kyber giảm từ 86 triệu USD (ngày 23/11) xuống còn 7,7 triệu USD ngày 1/12. Nguồn: DefiLlama" class="aligncenter" height="400" href="" id="" src="..." style="" width="800"/>
#        Tổng tài sản người dùng gửi vào dự án của Kyber giảm từ 86 triệu USD (ngày 23/11) xuống 7,7 triệu USD ngày 1/12. Nguồn: DefiLlama
#        [/caption]
#        </picture></div>
#
#        </figure><p class="" href="" id="" style=""><em class="" href="" id="" style="">BeInCrypto</em> đánh giá điều kiện hacker đưa ra "khá hài hước" nhưng đã phơi bày một thực tế đáng lo ngại về mô hình hoạt động của các sàn giao dịch phi tập trung. Bất chấp những tuyên bố về phân tán quyền lực, vụ tấn công và "hiệp ước" thương thảo cho thấy giao thức vẫn nằm trong tay một nhóm người. Đó là lý do hacker có thể tống tiền các giám đốc KyberSwap và đòi quyền kiểm soát.</p><p class="" href="" id="" style="">Trước đó ngày 23/11, tài khoản chính thức của Kyber Network thông báo trên X về việc KyberSwap Elastic gặp sự cố bảo mật và khuyến cáo người dùng nên rút tiền ngay lập tức. Tổng tài sản bị mất tương đương 47 triệu USD và tất cả được gửi vào một địa chỉ ví duy nhất.</p><p class="" href="" id="" style="">Kyber Network ra đời năm 2017 với ba nhà đồng sáng lập Lợi Lưu, Victor Tran và Yaron Velner. Đây là một trong những dự án blockchain đầu tiên do người Việt phát triển và thu hút sự chú ý lớn trên cộng đồng quốc tế. Dự án từng gọi vốn 52 triệu USD dưới hình thức ICO. Các sản phẩm chính của KyberNetwork là sàn giao dịch phi tập trung KyberSwap và nền tảng quản lý tài sản số Krystal.</p><p class="" href="" id="" style="">Dữ liệu từ <em class="" href="" id="" style="">DefiLlama</em> cho thấy tổng tài sản người dùng gửi vào dự án của Kyber giảm từ 86 triệu USD xuống còn 27 triệu USD sau thông tin KyberSwap Elastic bị tấn công được công bố. Đến 30/11, con số này giảm còn 7,17 triệu USD. Điều này cho thấy một đợt rút tiền khỏi nền tảng đã diễn ra ồ ạt.</p><div class="" data-component="true" data-component-type="tin_xemthem" data-component-value="4506948,4680243,4681682" data-thumb="1" href="" id="" style=""></div>
#        <!-- Hope -->
#        <!-- End Hope -->
#        <i>Nguồn: vnexpress.net</i></article>,
#        'title': 'Hacker đánh cắp 47 triệu USD của Kyber đòi quyền kiểm soát công ty',
#        'published_date': '2023-12-01'},
#       7: {'text': <article class="fck_detail"><strong class="" href="" id="" style="">Người đứng sau vụ hack nền tảng blockchain Việt Kyberswap yêu cầu có toàn bộ quyền kiểm soát công ty, đổi lại sẽ hoàn 50% số tiền đã lấy.</strong>
#        <p class="" href="" id="" style="">Một tuần sau khi tấn công vào KyberSwap Elastic, ngày 30/11, hacker đưa ra các điều kiện để hoàn số token tương đương 47 triệu USD đã đánh cắp. Người này đề nghị ban lãnh đạo công ty trao toàn quyền kiểm soát Kyber, quyền tạm thời với giao thức KyberDAO để thực hiện các thay đổi về bộ máy, mô hình quản trị.</p><p class="" href="" id="" style="">Hacker cũng muốn truy cập toàn bộ tài liệu, thông tin liên quan đến cấu trúc, hoạt động, doanh thu, lợi nhuận, tài sản, nợ phải trả, lương nhân viên, nhà đầu tư... của công ty.</p>
#        <figure class="" data-size="true" href="" id="" itemprop="associatedMedia image" itemscope="" itemtype="http://schema.org/ImageObject" style="">
#        <meta class="" content="https://vcdn-sohoa.vnecdn.net/2023/12/01/Kyber-jpeg-7997-1701418601.jpg?w=0&amp;h=0&amp;q=100&amp;dpr=2&amp;fit=crop&amp;s=VjEbSkPf6kK7XggiqGLARQ" href="" id="" itemprop="url" style=""/>
#        <meta class="" content="1200" href="" id="" itemprop="width" style=""/>
#        <meta class="" content="630" href="" id="" itemprop="height" style=""/>
#        <meta class="" content="" href="" id="" itemprop="href" style=""/>
#        <div class="" href="" id="" style=""><picture class="" href="" id="" style="">
#        <!--[if IE 9]><video style="display: none;"><![endif]-->
#        <source class="" data-srcset="https://vcdn-sohoa.vnecdn.net/2023/12/01/Kyber-jpeg-7997-1701418601.jpg?w=680&amp;h=0&amp;q=100&amp;dpr=1&amp;fit=crop&amp;s=YAD7hC6V4jsyp0SDFXdbuA 1x, https://vcdn-sohoa.vnecdn.net/2023/12/01/Kyber-jpeg-7997-1701418601.jpg?w=1020&amp;h=0&amp;q=100&amp;dpr=1&amp;fit=crop&amp;s=zaG30eSP-5m_N6wnRk6UkQ 1.5x, https://vcdn-sohoa.vnecdn.net/2023/12/01/Kyber-jpeg-7997-1701418601.jpg?w=680&amp;h=0&amp;q=100&amp;dpr=2&amp;fit=crop&amp;s=Y8QHCIH-RJz77L1-VOkK-g 2x" href="" id="" style=""/>
#        <!--[if IE 9]></video><![endif]-->
#        [caption id="" align="aligncenter" width="800"]<img alt="Minh họa với logo của KyberSwap. Ảnh: Coinmarketcap" class="aligncenter" height="400" href="" id="" src="..." style="" width="800"/>
#        Minh họa với logo của KyberSwap. Ảnh: Coinmarketcap
#        [/caption]
#        </picture></div>
#
#        </figure><p class="" href="" id="" style="">Bên tấn công cũng đòi Kyber nộp lại toàn bộ tài sản công ty, bao gồm cổ phiếu, vốn chủ sở hữu, token KNC và các token khác đang sở hữu. Thậm chí trang web, máy chủ, mật khẩu, mã, tài khoản mạng xã hội cũng nằm trong thỏa thuận.</p><p class="" href="" id="" style="">Đổi lại, hacker sẽ trả công ty số tiền đã lấy, trong khi ban lãnh đạo có thể mua lại Kyber với định giá phù hợp. Nhân viên chọn ở lại công ty sẽ được trả lương gấp đôi, còn nhân viên nghỉ việc được đền bù 12 tháng lương và hỗ trợ tìm việc với. "Những người đã gửi tiền vào nhóm thanh khoản của KyberSwap sẽ được hoàn trả 50% tài sản do những khoản lỗ liên quan đến biến động thị trường gần đây. Số tiền đó nhiều hơn những gì mọi người đáng được nhận", tin tặc viết.</p><p class="" href="" id="" style="">Hacker cho biết đây là lời đề nghị duy nhất, nếu không được đáp ứng trước ngày 10/12, thỏa thuận sẽ bị hủy.</p><p class="" href="" id="" style="">Đáp lại, CEO KyberNetwork Victor Tran, tuyên bố trên X ngày 30/11: "Không ai quan tâm đến người dùng Kyber như chúng tôi. Các bạn xứng đáng nhận được những gì tốt nhất. Thông điệp sẽ có vào ngày mai".</p><p class="" href="" id="" style="">Tuy nhiên, 19 giờ trôi qua, Kyber và các lãnh đạo công ty vẫn chưa đưa ra phản hồi thêm. Trong khi đó, tiểu sử trên X của Victor Tran có thêm dòng mô tả "just became a hunter" (mới thành thợ săn).</p><p class="" href="" id="" style="">Trước đó, trong thông báo đầu gửi đến hacker, đại diện Kyber cho biết sẽ tặng 10% số tiền nếu tin tặc trả lại token đánh cắp. CEO KyberSwap, cho biết nhóm đang nỗ lực lấy lại tiền và đưa hacker ra ánh sáng. Tuy nhiên, đến nay vẫn chưa có cam kết nào từ ban lãnh đạo Kyber về việc sẽ bồi thường cho người dùng.</p>
#        <figure class="" data-size="true" href="" id="" itemprop="associatedMedia image" itemscope="" itemtype="http://schema.org/ImageObject" style="">
#        <meta class="" content="https://vcdn-sohoa.vnecdn.net/2023/12/01/Screen-Shot-2023-12-01-at-15-0-4662-9275-1701418601.png?w=0&amp;h=0&amp;q=100&amp;dpr=2&amp;fit=crop&amp;s=CNmJg26tTmOHwZREPj2W5w" href="" id="" itemprop="url" style=""/>
#        <meta class="" content="1476" href="" id="" itemprop="width" style=""/>
#        <meta class="" content="740" href="" id="" itemprop="height" style=""/>
#        <meta class="" content="" href="" id="" itemprop="href" style=""/>
#        <div class="" href="" id="" style=""><picture class="" href="" id="" style="">
#        <!--[if IE 9]><video style="display: none;"><![endif]-->
#        <source class="" data-srcset="https://vcdn-sohoa.vnecdn.net/2023/12/01/Screen-Shot-2023-12-01-at-15-0-4662-9275-1701418601.png?w=680&amp;h=0&amp;q=100&amp;dpr=1&amp;fit=crop&amp;s=PuiXfSmBvLACCsGTdvk2iA 1x, https://vcdn-sohoa.vnecdn.net/2023/12/01/Screen-Shot-2023-12-01-at-15-0-4662-9275-1701418601.png?w=1020&amp;h=0&amp;q=100&amp;dpr=1&amp;fit=crop&amp;s=JJ2bXlXi4R5en09FOg630Q 1.5x, https://vcdn-sohoa.vnecdn.net/2023/12/01/Screen-Shot-2023-12-01-at-15-0-4662-9275-1701418601.png?w=680&amp;h=0&amp;q=100&amp;dpr=2&amp;fit=crop&amp;s=JN0x1ylUXeHEupmQbbBrAg 2x" href="" id="" style=""/>
#        <!--[if IE 9]></video><![endif]-->
#        [caption id="" align="aligncenter" width="800"]<img alt="Tổng tài sản người dùng gửi vào dự án của Kyber giảm từ 86 triệu USD (ngày 23/11) xuống còn 7,7 triệu USD ngày 1/12. Nguồn: DefiLlama" class="aligncenter" height="400" href="" id="" src="..." style="" width="800"/>
#        Tổng tài sản người dùng gửi vào dự án của Kyber giảm từ 86 triệu USD (ngày 23/11) xuống 7,7 triệu USD ngày 1/12. Nguồn: DefiLlama
#        [/caption]
#        </picture></div>
#
#        </figure><p class="" href="" id="" style=""><em class="" href="" id="" style="">BeInCrypto</em> đánh giá điều kiện hacker đưa ra "khá hài hước" nhưng đã phơi bày một thực tế đáng lo ngại về mô hình hoạt động của các sàn giao dịch phi tập trung. Bất chấp những tuyên bố về phân tán quyền lực, vụ tấn công và "hiệp ước" thương thảo cho thấy giao thức vẫn nằm trong tay một nhóm người. Đó là lý do hacker có thể tống tiền các giám đốc KyberSwap và đòi quyền kiểm soát.</p><p class="" href="" id="" style="">Trước đó ngày 23/11, tài khoản chính thức của Kyber Network thông báo trên X về việc KyberSwap Elastic gặp sự cố bảo mật và khuyến cáo người dùng nên rút tiền ngay lập tức. Tổng tài sản bị mất tương đương 47 triệu USD và tất cả được gửi vào một địa chỉ ví duy nhất.</p><p class="" href="" id="" style="">Kyber Network ra đời năm 2017 với ba nhà đồng sáng lập Lợi Lưu, Victor Tran và Yaron Velner. Đây là một trong những dự án blockchain đầu tiên do người Việt phát triển và thu hút sự chú ý lớn trên cộng đồng quốc tế. Dự án từng gọi vốn 52 triệu USD dưới hình thức ICO. Các sản phẩm chính của KyberNetwork là sàn giao dịch phi tập trung KyberSwap và nền tảng quản lý tài sản số Krystal.</p><p class="" href="" id="" style="">Dữ liệu từ <em class="" href="" id="" style="">DefiLlama</em> cho thấy tổng tài sản người dùng gửi vào dự án của Kyber giảm từ 86 triệu USD xuống còn 27 triệu USD sau thông tin KyberSwap Elastic bị tấn công được công bố. Đến 30/11, con số này giảm còn 7,17 triệu USD. Điều này cho thấy một đợt rút tiền khỏi nền tảng đã diễn ra ồ ạt.</p><div class="" data-component="true" data-component-type="tin_xemthem" data-component-value="4506948,4680243,4681682" data-thumb="1" href="" id="" style=""></div>
#        <!-- Hope -->
#        <!-- End Hope -->
#        <i>Nguồn: vnexpress.net</i></article>,
#        'title': 'Hacker đánh cắp 47 triệu USD của Kyber đòi quyền kiểm soát công ty',
#        'published_date': '2023-12-01'}}}}}}}

# %%
def get_content_vnexpress(url):
    # def get_content_autodaily()
    response = requests.get(url)
    time.sleep(5)
    soup = BeautifulSoup(response.content, 'html.parser')
    title = soup.find('h1').text.strip()
    date = soup.find('span', class_ = 'date').text.strip()
    published_date = convert_string(date)
    first_paragraph = soup.find('p', class_  = 'description')
    article = soup.find('article', class_ = 'fck_detail ')
    
    strong_tag = soup.new_tag('strong') 
    strong_tag.string = first_paragraph.text()  # Set the content of <i> tag


    # Insert the new element as the first child
    article.insert(0, strong_tag)
    first_paragraph
    for script_or_style in article(['script', 'style','iframe']):
                script_or_style.decompose()
    
    caption_text_list = article.find_all('figcaption')
    tags_to_remove = article.find_all(['a', 'span'])
    for tag in tags_to_remove:
        # Extract the text from the tag
        tag_text = tag.get_text()
        # Replace the tag with its text content
        tag.replace_with(tag_text)
        tag.text.strip()
    #for i in article.find_all('img'):
        #i.attrs = ['class', 'alt', 'src', 'data-original']
        #del i['onclick']
        #del i['style']
        #del i['class']
        #del i['alt']
    #remove all image attributes except somes from list
    list_attr = ['src','alt','data-src']
    for i in article.find_all('img'):
        for j in list(i.attrs.keys()):
            if j not in list_attr:
                i.attrs.pop(j)
    img_list = article.find_all('img')
    n_img = len(img_list)
    #print(len(caption_text_list))
    for i in range(0,n_img):
       
        caption_start = NavigableString("[caption id=\"\" align=\"aligncenter\" width=\"800\"]")
        try:
            caption_text = NavigableString(caption_text_list[i].get_text())
        except IndexError:
            caption_text = ''
        caption_end = NavigableString("[/caption]")
        # Insert the custom tags and caption text around the <img> tag
        img_list[i].insert_before(caption_start)
        img_list[i].insert_after(caption_end)
        img_list[i].insert_after(caption_text) 
    for i in article.find_all('img'):
        i['src'] = i['data-src']
    for i in caption_text_list:
        i.decompose()
        #print(img_list[i]['src'])
        #caption_text_list[i].decompose()
    for i in article.find_all(recursive = True):
        try:
            del i['onclick']
            i['id'] =''
            i['class']=''
            i['style'] =''
            i['href'] = ''
        except AttributeError:
            continue
        #try:
            #print(i)
            
        except TypeError:
            continue
    for i in article.find_all('img'):
        i['class'] = "aligncenter"
        i['width'] = 800
        i['height'] = 400
        del i['data-src']
    for item in article.find_all('div'):
        if item.string =="":
            item.decompose()
    source_tag = soup.new_tag('i') 
    source_tag.string = "Nguồn: autodaily.vn"  # Set the content of <i> tag
    
    # Append the <i> tag as the last child of the <article> tag
    article.append(source_tag)
    #Highlight the fist paragraph by using <strong> tag
    p_tag_1st = article.find_all('p')[0]
    p_text = p_tag_1st.get_text()
    # Create a new <strong> tag with the same text
    strong_tag = soup.new_tag("strong")
    strong_tag.string = p_text

    # Replace the <p> tag with the <strong> tag
    p_tag_1st.replace_with(strong_tag)
    return article, title, published_date
# Out:
# ['https://vnexpress.net/apple-phat-hanh-ban-cap-nhat-khan-cap-cho-iphone-4683660.html',
#  'https://vnexpress.net/hacker-danh-cap-47-trieu-usd-cua-kyber-doi-quyen-kiem-soat-cong-ty-4683507.html',
#  'https://vnexpress.net/sam-altman-noi-gi-sau-khi-tro-lai-openai-4683349.html',
#  'https://vnexpress.net/jack-ma-gay-sot-vi-binh-luan-voi-nhan-vien-luc-nua-dem-4682999.html',
#  'https://vnexpress.net/musk-danh-loi-tho-tuc-cho-nha-quang-cao-tay-chay-x-4683530.html',
#  'https://vnexpress.net/microsoft-tham-gia-hoi-dong-quan-tri-openai-4683344.html',
#  'https://vnexpress.net/lenh-cam-tiktok-cua-bang-montana-gap-can-tro-4683474.html',
#  'https://vnexpress.net/them-ceo-cua-cong-ty-ai-ty-usd-bi-ep-tu-chuc-4683338.html',
#  'https://vnexpress.net/musk-tiep-tuc-hoai-nghi-ve-ai-nguy-hiem-tai-openai-4683236.html']

# %%
convert_string('Thứ sáu, 1/12/2023, 15:28 (GMT+7)')
# Out:
# ('2023-12-01', datetime.datetime(2023, 12, 1, 0, 0))

# %%
response = requests.get('https://vnexpress.net/hacker-danh-cap-47-trieu-usd-cua-kyber-doi-quyen-kiem-soat-cong-ty-4683507.html')
time.sleep(5)
soup = BeautifulSoup(response.content, 'html5lib')
title = soup.find('h1').text.strip()
date = soup.find('span', class_ = 'date').text.strip()
published_date = convert_string(date)[0]
first_paragraph = soup.find('p', class_  = 'description')
article = soup.find('article', class_ = 'fck_detail')

strong_tag = soup.new_tag('strong') 
strong_tag.string = first_paragraph.text # Set the content of <i> tag


# Insert the new element as the first child
article.insert(0, strong_tag)
first_paragraph
for script_or_style in article(['script', 'style','iframe','video']):
            script_or_style.decompose()

caption_text_list = article.find_all('figcaption')
tags_to_remove = article.find_all(['a', 'span'])
for tag in tags_to_remove:
    # Extract the text from the tag
    tag_text = tag.get_text()
    # Replace the tag with its text content
    tag.replace_with(tag_text)
    tag.text.strip()
#remove all image attributes except somes from list
list_attr = ['src','alt','data-src']
for i in article.find_all('img'):
    for j in list(i.attrs.keys()):
        if j not in list_attr:
            i.attrs.pop(j)
img_list = article.find_all('img')
n_img = len(img_list)
for i in range(0,n_img):
       
    caption_start = NavigableString("[caption id=\"\" align=\"aligncenter\" width=\"800\"]")
    try:
        caption_text = NavigableString(caption_text_list[i].get_text())
    except IndexError:
        caption_text = ''
    caption_end = NavigableString("[/caption]")
    # Insert the custom tags and caption text around the <img> tag
    img_list[i].insert_before(caption_start)
    img_list[i].insert_after(caption_end)
    img_list[i].insert_after(caption_text) 
for i in article.find_all('img'):
    try:
        i['src'] = i['data-src']
    except KeyError:
        continue
for i in caption_text_list:
    i.decompose()
"""for i in article.find_all(recursive = True):
        try:
            del i['onclick']
            i['id'] =''
            i['class']=''
            i['style'] =''
            i['href'] = ''
        except AttributeError:
            continue
        #try:
            #print(i)
            
        except TypeError:
            continue"""
for i in article.find_all('img'):
    i['class'] = "aligncenter"
    i['width'] = 800
    i['height'] = 400
    del i['data-src']
list_attr = ['src','alt','data-src','class']
for i in article.find_all(recursive = True):
    for j in list(i.attrs.keys()):
        if j not in list_attr:
            i.attrs.pop(j)
for item in article.find_all('div'):
    if item.string =="":
        item.decompose()
    
article.find_all('p',recursive = True)[-1].decompose()
#article.find_all(recursive = True)[-1].decompose()
#article.find('div', class_ ='width_common box-tinlienquanv2').decompose()
source_tag = soup.new_tag('i') 
source_tag.string = "Nguồn: vnexpress.net"  # Set the content of <i> tag
article.append(source_tag)

# %%
article
# Out:
# <article class="fck_detail"><strong>Người đứng sau vụ hack nền tảng blockchain Việt Kyberswap yêu cầu có toàn bộ quyền kiểm soát công ty, đổi lại sẽ hoàn 50% số tiền đã lấy.</strong>
# <p class="Normal">Một tuần sau khi tấn công vào KyberSwap Elastic, ngày 30/11, hacker đưa ra các điều kiện để hoàn số token tương đương 47 triệu USD đã đánh cắp. Người này đề nghị ban lãnh đạo công ty trao toàn quyền kiểm soát Kyber, quyền tạm thời với giao thức KyberDAO để thực hiện các thay đổi về bộ máy, mô hình quản trị.</p><p class="Normal">Hacker cũng muốn truy cập toàn bộ tài liệu, thông tin liên quan đến cấu trúc, hoạt động, doanh thu, lợi nhuận, tài sản, nợ phải trả, lương nhân viên, nhà đầu tư... của công ty.</p><figure class="tplCaption"><div class="fig-picture">[caption id="" align="aligncenter" width="800"]<img alt="Minh họa với logo của KyberSwap. Ảnh: Coinmarketcap" class="aligncenter" src="https://vcdn-sohoa.vnecdn.net/2023/12/01/Kyber-jpeg-7997-1701418601.jpg"/>Minh họa với logo của KyberSwap. Ảnh: Coinmarketcap[/caption]</div></figure><p class="Normal">Bên tấn công cũng đòi Kyber nộp lại toàn bộ tài sản công ty, bao gồm cổ phiếu, vốn chủ sở hữu, token KNC và các token khác đang sở hữu. Thậm chí trang web, máy chủ, mật khẩu, mã, tài khoản mạng xã hội cũng nằm trong thỏa thuận.</p><p class="Normal">Đổi lại, hacker sẽ trả công ty số tiền đã lấy, trong khi ban lãnh đạo có thể mua lại Kyber với định giá phù hợp. Nhân viên chọn ở lại công ty sẽ được trả lương gấp đôi, còn nhân viên nghỉ việc được đền bù 12 tháng lương và hỗ trợ tìm việc với. "Những người đã gửi tiền vào nhóm thanh khoản của KyberSwap sẽ được hoàn trả 50% tài sản do những khoản lỗ liên quan đến biến động thị trường gần đây. Số tiền đó nhiều hơn những gì mọi người đáng được nhận", tin tặc viết.</p><p class="Normal">Hacker cho biết đây là lời đề nghị duy nhất, nếu không được đáp ứng trước ngày 10/12, thỏa thuận sẽ bị hủy.</p><p class="Normal">Đáp lại, CEO KyberNetwork Victor Tran, tuyên bố trên X ngày 30/11: "Không ai quan tâm đến người dùng Kyber như chúng tôi. Các bạn xứng đáng nhận được những gì tốt nhất. Thông điệp sẽ có vào ngày mai".</p><p class="Normal">Tuy nhiên, 19 giờ trôi qua, Kyber và các lãnh đạo công ty vẫn chưa đưa ra phản hồi thêm. Trong khi đó, tiểu sử trên X của Victor Tran có thêm dòng mô tả "just became a hunter" (mới thành thợ săn).</p><p class="Normal">Trước đó, trong thông báo đầu gửi đến hacker, đại diện Kyber cho biết sẽ tặng 10% số tiền nếu tin tặc trả lại token đánh cắp. CEO KyberSwap, cho biết nhóm đang nỗ lực lấy lại tiền và đưa hacker ra ánh sáng. Tuy nhiên, đến nay vẫn chưa có cam kết nào từ ban lãnh đạo Kyber về việc sẽ bồi thường cho người dùng.</p><figure class="tplCaption"><div class="fig-picture">[caption id="" align="aligncenter" width="800"]<img alt="Tổng tài sản người dùng gửi vào dự án của Kyber giảm từ 86 triệu USD (ngày 23/11) xuống còn 7,7 triệu USD ngày 1/12. Nguồn: DefiLlama" class="aligncenter" src="https://vcdn-sohoa.vnecdn.net/2023/12/01/Screen-Shot-2023-12-01-at-15-0-4662-9275-1701418601.png"/>Tổng tài sản người dùng gửi vào dự án của Kyber giảm từ 86 triệu USD (ngày 23/11) xuống 7,7 triệu USD ngày 1/12. Nguồn: DefiLlama[/caption]</div></figure><p class="Normal"><em>BeInCrypto</em> đánh giá điều kiện hacker đưa ra "khá hài hước" nhưng đã phơi bày một thực tế đáng lo ngại về mô hình hoạt động của các sàn giao dịch phi tập trung. Bất chấp những tuyên bố về phân tán quyền lực, vụ tấn công và "hiệp ước" thương thảo cho thấy giao thức vẫn nằm trong tay một nhóm người. Đó là lý do hacker có thể tống tiền các giám đốc KyberSwap và đòi quyền kiểm soát.</p><p class="Normal">Trước đó ngày 23/11, tài khoản chính thức của Kyber Network thông báo trên X về việc KyberSwap Elastic gặp sự cố bảo mật và khuyến cáo người dùng nên rút tiền ngay lập tức. Tổng tài sản bị mất tương đương 47 triệu USD và tất cả được gửi vào một địa chỉ ví duy nhất.</p><p class="Normal">Kyber Network ra đời năm 2017 với ba nhà đồng sáng lập Lợi Lưu, Victor Tran và Yaron Velner. Đây là một trong những dự án blockchain đầu tiên do người Việt phát triển và thu hút sự chú ý lớn trên cộng đồng quốc tế. Dự án từng gọi vốn 52 triệu USD dưới hình thức ...
# <!-- Hope -->
# <!-- End Hope -->
# <i>Nguồn: vnexpress.net</i></article>
